# %% [markdown]
# # NSF Computer and Information Science and Engineering (CISE)
#
# - `0505****`: Division of Computer and Network Systems (CNS)
# - `0501****`: Division of Computing and Communication Foundations (CCF)
# - `0502****`: Division of Information and Intelligent Systems (IIS)
# - `0509****`: Office of Advanced Cyberinfrastructure (OAC)

# %%
import os,sys,json
import core.coworknet, core.nsf_utils
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import networkx as nx
import seaborn as sns
import pandas as pd
from datetime import datetime
from collections import Counter

# %%
grant_type = ["Standard Grant", "Continuing grant"] # draw only these types
div_type = {
    "0505": "Division of Computer and Network Systems (CNS)",
    "0501": "Division of Computing and Communication Foundations (CCF)",
    "0502": "Division of Information and Intelligent Systems (IIS)",
    "0509": "Office of Advanced Cyberinfrastructure (OAC)"
}

# %%
def histogram_num_pis(data, years, orgcodes):
    plt.title("[NSF {}-{}] histogram - number of PIs".format(years[0], years[-1]))
    plt.ylabel("Number of grants")
    plt.xlabel("Number of PIs")
    pis = [d["num_pis"] for d in data.values() if d["org"][:4] in orgcodes]
    counter_pis = Counter(pis)
    print(counter_pis)
    x = range(1, 10)
    y = [counter_pis[i] if i in counter_pis else 0 for i in x]
    plt.bar(x, y)

# %%
data = {}
years = [2004]
for y in years:
    data.update(core.nsf_utils.load_numpub_data(y))
data = {k:v for k, v in data.items() if v["type"] in grant_type}
for y in years:
    print("[{}]".format(y))
    print("Total number of grants", len([v for v in data.values() if v["year"] == y]))
    for code, desc in div_type.items():
        print(desc, len([v for v in data.values() if v["org"][:4] == code and v["year"] == y]))
# Out:
# [2004]
# Total number of grants 10212
# Division of Computer and Network Systems (CNS) 413
# Division of Computing and Communication Foundations (CCF) 349
# Division of Information and Intelligent Systems (IIS) 365
# Office of Advanced Cyberinfrastructure (OAC) 53

# %%
histogram_num_pis(data, years, div_type.keys())
# Out:
# Counter({1: 653, 2: 246, 3: 125, 5: 84, 4: 63, 6: 4, 0: 2, 7: 2, 8: 1})

# %%
grant_list = [k for k, d in data.items() if d["org"][:4] in div_type.keys() and d["num_pis"] == 2]
print(grant_list)
# Out:
# ['0401049', '0403020', '0403130', '0403590', '0404001', '0404011', '0404193', '0404297', '0404440', '0406305', '0406345', '0406384', '0410203', '0410246', '0410409', '0410524', '0410553', '0410771', '0410790', '0410918', '0410937', '0411127', '0411152', '0411307', '0412029', '0412858', '0412884', '0412894', '0412930', '0412965', '0413012', '0413078', '0413085', '0413138', '0413196', '0413214', '0413227', '0413251', '0413284', '0413321', '0413328', '0413709', '0414380', '0414409', '0414482', '0414557', '0414567', '0414630', '0414710', '0414762', '0414763', '0414791', '0414815', '0414976', '0414981', '0415016', '0415021', '0415101', '0415175', '0415195', '0415257', '0415865', '0415923', '0416364', '0417607', '0418165', '0420337', '0420434', '0420505', '0420866', '0420873', '0420906', '0420985', '0423014', '0423039', '0423070', '0423253', '0423305', '0423546', '0423584', '0424601', '0426021', '0426557', '0426627', '0426674', '0426879', '0426904', '0427260', '0427385', '0427695', '0428427', '0429154', '0429211', '0429228', '0429364', '0429365', '0429454', '0429469', '0429481', '0429535', '0429591', '0429631', '0429640', '0429653', '0429711', '0429743', '0429766', '0429781', '0429836', '0429930', '0429948', '0430061', '0430063', '0430077', '0430166', '0430228', '0430258', '0430271', '0430303', '0430304', '0430318', '0430402', '0430474', '0430477', '0430487', '0430510', '0430593', '0430654', '0430742', '0430781', '0430822', '0430848', '0430849', '0430853', '0430885', '0430892', '0430915', '0430954', '0430994', '0431024', '0431030', '0431031', '0431051', '0431059', '0431069', '0431088', '0431128', '0431150', '0431166', '0431177', '0432009', '0432038', '0432063', '0432098', '0432116', '0432186', '0432297', '0432881', '0433392', '0433454', '0434078', '0434120', '0434211', '0434410', '0434512', '0434533', '0434816', '0434824', '0434996', '0435023', '0435043', '0435060', '0435065', '0435087', '0435111', '0435134', '0435157', '0435247', '0435272', '0435292', '0435303', '0435381', '0435429', '0435480', '0435505', '0435517', '0435531', '0437603', '0437810', '0438263', '0438314', '0438372', '0438803', '0438848', '0438871', '0438923', '0438948', '0439034', '0439061', '0440021', '0440133', '0440443', '0441172', '0441999', '0442128', '0443162', '0443257', '0443591', '0444412', '0444417', '0444486', '0447079', '0447973', '0449573', '0450112', '0451097', '0451431', '0452180', '0452235', '0453456', '0453459', '0453463', '0453491', '0453498', '0453545', '0453552', '0453604', '0454018', '0454056', '0454062', '0454130', '0454174', '0454189', '0454195', '0454233', '0454381', '0454416', '0454425', '0454437', '0455361', '0455997', '0455998', '0456001', '0456017', '0456026', '0456129']

# %%
grant_list = [k for k, d in data.items() if d["org"][:4] in div_type.keys() and d["num_pis"] == 2]
print(len(grant_list), "grants with 2 PIs")
# Out:
# 246 grants with 2 PIs

# %%
no_publications = []
no_edges = []
other = []
only_one_pi = []
two_separate = []
two_cowork = []
for pid in grant_list:
    award, table, ts, te, G_all = core.coworknet.get_grant_coworknet_pis(pid)
    if len(table) == 0:
        no_publications.append(pid)
        continue
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
    G = G_all.subgraph(pis)
        
    working_pis = []
    reported_pub_number = 0
    for k, v in table.items():
        if v["type"]: # only count publicatoins in-grant
            reported_pub_number += 1
            working_pis.append([a for a, av in v["authors"].items() if av["pi"]])
    # print(pid, working_pis)
    pi_counter = [set([n[0]+n.split(" ")[-1] for n in group]) for group in working_pis]
    pi_union = set.union(*pi_counter)
    pi_max_group = max([len(pg) for pg in pi_counter])
#     print(pi_counter, pi_union, pi_max_group)
    print("{} union={}, max_group={}, numpub={} {} {}".format(pid, len(pi_union), pi_max_group, reported_pub_number, len(table), len(G.edges)))
    if len(pi_union) == 2 and pi_max_group == 2:
        two_cowork.append(pid)
    elif len(pi_union) == 2:
        two_separate.append(pid)
    elif len(pi_union) == 1:
        only_one_pi.append(pid)
    else:
        other.append(pid)
print("{} ({:.2f}%) grants have no publication".format(len(no_publications), 100*len(no_publications)/len(grant_list)))
print("{} ({:.2f}%) grants have only one working PI".format(len(only_one_pi), 100*len(only_one_pi)/len(grant_list)))
print("{} ({:.2f}%) grants have two PIs working separately".format(len(two_separate), 100*len(two_separate)/len(grant_list)))
print("{} ({:.2f}%) grants have two PIs collaborated".format(len(two_cowork), 100*len(two_cowork)/len(grant_list)))
print("{} ({:.2f}%) grants are unknown".format(len(other), 100*len(other)/len(grant_list)))
# Out:
# 0404297 union=2, max_group=2, numpub=3 6 5
# 0410203 union=2, max_group=2, numpub=6 6 1
# 0410246 union=2, max_group=2, numpub=13 16 4
# 0410409 union=1, max_group=1, numpub=2 2 0
# 0410553 union=2, max_group=2, numpub=7 8 3
# 0410771 union=2, max_group=2, numpub=9 15 9
# 0410918 union=2, max_group=2, numpub=8 18 12
# 0410937 union=2, max_group=2, numpub=19 40 27
# 0411127 union=2, max_group=2, numpub=1 41 41
# 0411152 union=0, max_group=0, numpub=1 1 0
# 0411307 union=2, max_group=2, numpub=6 33 29
# 0412029 union=1, max_group=1, numpub=1 1 0
# 0412884 union=1, max_group=1, numpub=8 8 0
# 0412894 union=1, max_group=1, numpub=7 7 0
# 0412930 union=2, max_group=2, numpub=12 12 1
# 0413012 union=2, max_group=2, numpub=2 5 4
# 0413078 union=1, max_group=1, numpub=3 3 0
# 0413085 union=2, max_group=2, numpub=4 16 15
# 0413138 union=2, max_group=2, numpub=10 10 1
# 0413196 union=1, max_group=1, numpub=23 23 0
# 0413214 union=2, max_group=1, numpub=16 16 0
# 0413227 union=2, max_group=2, numpub=4 13 12
# 0413251 union=2, max_group=2, numpub=1 5 5
# 0413284 union=1, max_group=1, numpub=3 3 0
# 0413321 union=2, max_group=2, numpub=2 4 3
# 0414380 union=2, max_group=2, numpub=9 70 70
# 0414482 union=2, max_group=2, numpub=5 9 8
# 0414557 union=2, max_group=1, numpub=5 5 0
# 0414567 union=2, max_group=2, numpub=18 42 38
# 0414630 union=2, max_group=2, numpub=6 13 10
# 0414710 union=2, max_group=2, numpub=15 17 4
# 0414762 union=1, max_group=1, numpub=4 4 0
# 0414763 union=2, max_group=2, numpub=9 9 1
# 0414791 union=2, max_group=2, numpub=10 19 11
# 0414815 union=0, max_group=0, numpub=3 3 0
# 0414976 union=2, max_group=2, numpub=2 12 11
# 0414981 union=2, max_group=2, numpub=18 18 4
# 0415021 union=1, max_group=1, numpub=2 2 0
# 0415101 union=1, max_group=1, numpub=1 1 0
# 0415175 union=2, max_group=1, numpub=12 12 0
# 0415195 union=2, max_group=2, numpub=21 21 1
# 0415257 union=2, max_group=2, numpub=10 23 19
# 0415865 union=2, max_group=2, numpub=8 9 2
# 0416364 union=1, max_group=1, numpub=2 2 0
# 0417607 union=2, max_group=1, numpub=6 6 0
# 0418165 union=2, max_group=2, numpub=3 3 1
# 0420434 union=1, max_group=1, numpub=9 9 0
# 0420866 union=1, max_group=1, numpub=8 8 0
# 0423039 union=2, max_group=2, numpub=1 20 20
# 0423253 union=2, max_group=2, numpub=21 21 1
# 0423546 union=2, max_group=1, numpub=6 6 0
# 0426557 union=2, max_group=2, numpub=2 4 3
# 0426627 union=2, max_group=2, numpub=12 19 8
# 0426674 union=2, max_group=2, numpub=13 20 8
# 0426904 union=0, max_group=0, numpub=3 3 0
# 0427260 union=2, max_group=1, numpub=13 13 0
# 0427385 union=1, max_group=1, numpub=8 8 0
# 0427695 union=2, max_group=2, numpub=17 31 23
# 0428427 union=2, max_group=2, numpub=20 21 2
# 0429154 union=2, max_group=2, numpub=2 6 6
# 0429211 union=1, max_group=1, numpub=11 11 0
# 0429228 union=2, max_group=2, numpub=3 6 6
# 0429364 union=2, max_group=2, numpub=11 44 37
# 0429365 union=1, max_group=1, numpub=1 1 0
# 0429481 union=2, max_group=1, numpub=9 9 0
# 0429535 union=2, max_group=1, numpub=13 13 0
# 0429591 union=1, max_group=1, numpub=36 36 0
# 0429631 union=3, max_group=2, numpub=13 36 33
# 0429640 union=2, max_group=2, numpub=5 5 2
# 0429653 union=1, max_group=1, numpub=21 21 0
# 0429711 union=2, max_group=2, numpub=5 9 5
# 0429766 union=2, max_group=2, numpub=7 111 111
# 0429836 union=2, max_group=2, numpub=2 7 6
# 0429930 union=2, max_group=2, numpub=19 25 14
# 0429948 union=2, max_group=2, numpub=5 9 7
# 0430061 union=2, max_group=1, numpub=8 8 0
# 0430063 union=1, max_group=1, numpub=8 8 0
# 0430077 union=1, max_group=1, numpub=4 4 0
# 0430166 union=1, max_group=1, numpub=14 14 0
# 0430228 union=1, max_group=1, numpub=3 3 0
# 0430258 union=1, max_group=1, numpub=3 3 0
# 0430271 union=2, max_group=2, numpub=4 8 5
# 0430303 union=2, max_group=2, numpub=7 87 87
# 0430304 union=2, max_group=2, numpub=5 39 37
# 0430318 union=2, max_group=2, numpub=3 14 14
# 0430402 union=2, max_group=2, numpub=18 66 50
# 0430474 union=1, max_group=1, numpub=5 5 0
# 0430477 union=2, max_group=2, numpub=7 33 30
# 0430487 union=2, max_group=2, numpub=31 31 4
# 0430510 union=2, max_group=2, numpub=8 43 38
# 0430654 union=1, max_group=1, numpub=15 15 0
# 0430742 union=1, max_group=1, numpub=5 5 0
# 0430781 union=2, max_group=2, numpub=29 255 4
# 0430848 union=1, max_group=1, numpub=9 9 0
# 0430849 union=2, max_group=2, numpub=5 44 40
# 0430853 union=1, max_group=1, numpub=2 2 0
# 0430885 union=2, max_group=2, numpub=22 46 30
# 0430915 union=2, max_group=1, numpub=12 12 0
# 0430954 union=2, max_group=1, numpub=14 14 0
# 0430994 union=2, max_group=2, numpub=8 30 26
# 0431024 union=2, max_group=2, numpub=7 54 52
# 0431030 union=2, max_group=2, numpub=61 144 94
# 0431031 union=2, max_group=2, numpub=37 44 9
# 0431059 union=2, max_group=2, numpub=18 53 43
# 0431069 union=1, max_group=1, numpub=7 7 0
# 0431088 union=2, max_group=2, numpub=25 35 12
# 0431150 union=2, max_group=2, numpub=50 50 2
# 0431166 union=2, max_group=2, numpub=2 18 18
# 0431177 union=2, max_group=1, numpub=13 13 0
# 0432009 union=2, max_group=1, numpub=18 18 0
# 0432063 union=2, max_group=2, numpub=5 6 3
# 0432098 union=2, max_group=2, numpub=20 32 14
# 0432186 union=1, max_group=1, numpub=2 2 0
# 0432881 union=0, max_group=0, numpub=1 1 0
# 0434410 union=2, max_group=2, numpub=8 10 4
# 0434533 union=1, max_group=1, numpub=10 10 0
# 0434996 union=2, max_group=2, numpub=4 11 11
# 0435023 union=1, max_group=1, numpub=4 4 0
# 0435060 union=1, max_group=1, numpub=3 3 0
# 0435065 union=2, max_group=2, numpub=17 51 37
# 0435111 union=2, max_group=2, numpub=20 21 3
# 0435157 union=1, max_group=1, numpub=2 2 0
# 0435247 union=2, max_group=2, numpub=13 13 4
# 0435272 union=2, max_group=2, numpub=1 36 36
# 0435303 union=2, max_group=2, numpub=14 21 13
# 0435381 union=1, max_group=1, numpub=13 13 0
# 0435429 union=1, max_group=1, numpub=6 6 0
# 0435505 union=2, max_group=2, numpub=15 26 12
# 0435517 union=2, max_group=2, numpub=3 24 23
# 0435531 union=1, max_group=1, numpub=8 8 0
# 0437810 union=2, max_group=2, numpub=9 28 21
# 0438263 union=2, max_group=2, numpub=20 34 27
# 0438314 union=1, max_group=1, numpub=8 8 0
# 0438923 union=1, max_group=1, numpub=4 4 0
# 0444412 union=1, max_group=1, numpub=2 2 0
# 0444417 union=2, max_group=2, numpub=4 4 1
# 0444486 union=2, max_group=1, numpub=13 13 0
# 0452235 union=0, max_group=0, numpub=4 4 0
# 0453456 union=2, max_group=2, numpub=8 96 94
# 0453459 union=2, max_group=2, numpub=8 24 21
# 0453463 union=2, max_group=2, numpub=13 45 40
# 0453545 union=0, max_group=0, numpub=1 1 0
# 0454062 union=2, max_group=2, numpub=3 20 19
# 0454233 union=2, max_group=2, numpub=19 45 40
# 0454381 union=1, max_group=1, numpub=6 6 0
# 0454416 union=2, max_group=2, numpub=2 11 10
# 0454425 union=1, max_group=1, numpub=28 28 0
# 0455998 union=2, max_group=2, numpub=3 30 29
# 0456001 union=2, max_group=1, numpub=17 17 0
# 97 (39.43%) grants have no publication
# 42 (17.07%) grants have only one working PI
# 15 (6.10%) grants have two PIs working separately
# 85 (34.55%) grants have two PIs collaborated
# 7 (2.85%) grants are unknown

# %%
collab_type = {}
dict_period = {}
dict_amount = {}
dict_teams = {}
dict_publications = {}
dict_citations = {}
dict_timestamps = {}
convert_t = lambda t: datetime.strptime(t, "%Y-%m-%dT%X")

for grant_id in grant_list:
    award,_,ts,te,G_all = core.coworknet.get_grant_coworknet_pis(grant_id)
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
#     print(pis)
    G = G_all.subgraph(pis)
#     if len(G.edges) == 0:
#         continue
        
#     print(grant_id)
    publications = {"pre-grant":0, "grant":0, "post-grant":0}
    citations = {"pre-grant":0, "grant":0, "post-grant":0}
    teams = {"pre-grant":0, "grant":0, "post-grant":0}
    dates = [convert_t(data["date"]) for _,_,data in G.edges.data()]
    for u,v,data in G.edges.data():
#         print(data["paper"])
        coauthor = set()
        for e in G_all.edges.data():
            if e[2]["paper"] == data["paper"]:
                coauthor.update([e[0], e[1]])
        num_coauthor = len(coauthor)
#         print(data["paper"], num_coauthor)
        print(grant_id, data["paper"], num_coauthor)
        
#         print(data["paper"], num_coauthor)
        if data["grant"] != "other" or (ts <= convert_t(data["date"]) and convert_t(data["date"]) <= te):
#             print("grant") # reported publications or unreported pubs in the grant period
            teams["grant"] += num_coauthor
            publications["grant"] += 1
            citations["grant"] += data["citation"]
        elif convert_t(data["date"]) < ts:
#             print("pre-grant") # unreported publications before the grant period
            teams["pre-grant"] += num_coauthor
            publications["pre-grant"] += 1
            citations["pre-grant"] += data["citation"]
        elif te < convert_t(data["date"]):
#             print("post-grant") # unreported publications after the grant period
            teams["post-grant"] += num_coauthor
            publications["post-grant"] += 1
            citations["post-grant"] += data["citation"]
    dict_period[grant_id] = (te-ts).days
    dict_amount[grant_id] = award["awardAmount"]
    dict_teams[grant_id] = teams
    dict_publications[grant_id] = publications
    dict_citations[grant_id] = citations
    dict_timestamps[grant_id] = sorted(dates)
#     print(publications, dict_timestamps[grant_id])

ctypes = []
for gid, v in dict_publications.items():
    collab_type[gid] = "{}{}{}".format(1 if v["pre-grant"]>0 else 0, 1 if v["grant"]>0 else 0, 1 if v["post-grant"]>0 else 0)
    ctypes.append(collab_type[gid])

print(len([k for k in dict_timestamps.keys() if collab_type[k] != "000"]), "grants - two PIs collaborated")
print(Counter(ctypes))
# Out:
# 0404297 2599364901 5
# 0404297 1548079979 5
# 0404297 1993760683 5
# 0404297 188386583 5
# 0404297 2098491294 5
# 0410203 2507902825 3
# 0410246 80472130 3
# 0410246 2040308490 4
# 0410246 2150315571 3
# 0410246 2327590935 4
# 0410553 2166402976 3
# 0410553 2154209908 3
# 0410553 2117040175 3
# 0410771 1988124224 3
# 0410771 1591040101 4
# 0410771 2134940363 2
# 0410771 2098811885 4
# 0410771 2133448173 4
# 0410771 1959073722 4
# 0410771 2143636443 4
# 0410771 2059065724 3
# 0410771 2103052126 3
# 0410918 2013854854 3
# 0410918 2161903763 3
# 0410918 2188508564 4
# 0410918 2102039064 3
# 0410918 105131483 4
# 0410918 137017884 3
# 0410918 2189618275 3
# 0410918 2172023269 3
# 0410918 2103816232 5
# 0410918 1551162551 3
# 0410918 2106244281 3
# 0410918 175055547 4
# 0410937 2098540801 4
# 0410937 2114331787 3
# 0410937 2013863826 4
# 0410937 2891254164 3
# 0410937 2024945307 7
# 0410937 2091483166 3
# 0410937 2144416297 4
# 0410937 2038101290 3
# 0410937 2168014130 11
# 0410937 2147481669 5
# 0410937 2113924808 7
# 0410937 2010890189 5
# 0410937 2044062670 4
# 0410937 74208207 5
# 0410937 1495104217 3
# 0410937 74697690 3
# 0410937 1513140061 3
# 0410937 2159129693 7
# 0410937 2053794660 4
# 0410937 1973609317 3
# 0410937 2158199659 7
# 0410937 76871532 3
# 0410937 2092959345 3
# 0410937 1987554710 5
# 0410937 2132484797 5
# 0410937 2017472544 8
# 0410937 2115412309 8
# 0411127 1495755138 4
# 0411127 2129763083 6
# 0411127 1554022546 5
# 0411127 2106704917 4
# 0411127 2144825886 8
# 0411127 153284256 4
# 0411127 2127003812 5
# 0411127 1967808040 6
# 0411127 2093045420 6
# 0411127 2120103599 4
# 0411127 2300850351 3
# 0411127 1911230769 10
# 0411127 2316746035 5
# 0411127 2009470771 14
# 0411127 1557386039 5
# 0411127 2108730429 6
# 0411127 1846941757 4
# 0411127 200075328 4
# 0411127 2169656512 3
# 0411127 2097653958 6
# 0411127 2110783687 5
# 0411127 2058367048 10
# 0411127 2137797833 6
# 0411127 1975670601 7
# 0411127 2105299911 4
# 0411127 1554732238 4
# 0411127 99459794 4
# 0411127 2133766356 7
# 0411127 2149998172 5
# 0411127 1549821534 5
# 0411127 204839006 5
# 0411127 2066232031 5
# 0411127 2208253025 6
# 0411127 2122718561 9
# 0411127 2028660451 3
# 0411127 2261165542 6
# 0411127 1934130410 6
# 0411127 2169842412 5
# 0411127 2518764271 9
# 0411127 2724923505 7
# 0411127 2107221757 5
# 0411307 1513977472 7
# 0411307 2013592197 8
# 0411307 2148147078 4
# 0411307 2043405198 5
# 0411307 1656271119 7
# 0411307 1888219919 7
# 0411307 95608104 18
# 0411307 1520369706 4
# 0411307 2112831787 7
# 0411307 2048014508 7
# 0411307 1949970607 3
# 0411307 2132721976 3
# 0411307 2069563322 6
# 0411307 28420799 5
# 0411307 1603133761 5
# 0411307 2159840202 6
# 0411307 156208468 4
# 0411307 1597689557 4
# 0411307 1998631637 9
# 0411307 1707787606 8
# 0411307 1697496154 7
# 0411307 120340316 6
# 0411307 2140337761 9
# 0411307 2125580772 8
# 0411307 2216311525 8
# 0411307 2032298737 5
# 0411307 1602302837 5
# 0411307 1975102717 4
# 0411307 2023593470 5
# 0412930 1982414171 3
# 0413012 2040698665 3
# 0413012 2001131675 3
# 0413012 2030602281 3
# 0413012 48329127 3
# 0413085 2117483530 3
# 0413085 1543362959 3
# 0413085 178451601 10
# 0413085 2120338134 7
# 0413085 2022972697 5
# 0413085 2156912221 4
# 0413085 2143507168 3
# 0413085 2154325666 3
# 0413085 2110534947 9
# 0413085 2022240548 3
# 0413085 2112869159 10
# 0413085 2167816621 6
# 0413085 2128935791 5
# 0413085 2026189431 3
# 0413085 2158438332 3
# 0413138 2060749138 3
# 0413227 2045014786 3
# 0413227 2097306564 3
# 0413227 2130055305 3
# 0413227 2141017688 3
# 0413227 2028464120 3
# 0413227 2111000344 5
# 0413227 1977001952 2
# 0413227 2158428710 4
# 0413227 2123577644 4
# 0413227 2062174770 2
# 0413227 2131768312 2
# 0413227 2266232061 2
# 0413251 2098573425 3
# 0413251 2123031219 3
# 0413251 2125657140 3
# 0413251 2045243672 3
# 0413251 2107034328 3
# 0413321 247364113 3
# 0413321 2138328817 4
# 0413321 593221263 8
# 0414380 2165966087 3
# 0414380 143908874 6
# 0414380 1968942346 3
# 0414380 2081536787 7
# 0414380 1786705683 6
# 0414380 64214819 3
# 0414380 2073246757 6
# 0414380 2041239340 4
# 0414380 2054235951 3
# 0414380 1500245553 4
# 0414380 2003177010 3
# 0414380 2166775858 6
# 0414380 2021076785 4
# 0414380 2151308089 3
# 0414380 2170122555 4
# 0414380 1781211963 3
# 0414380 2114309694 5
# 0414380 2470613324 3
# 0414380 161412946 3
# 0414380 2592514134 3
# 0414380 2294949718 3
# 0414380 2572937304 4
# 0414380 2155384665 4
# 0414380 2164974682 3
# 0414380 2060829018 4
# 0414380 2158778465 4
# 0414380 2163925089 3
# 0414380 1488816737 3
# 0414380 2150598760 3
# 0414380 2113353068 6
# 0414380 2038430060 3
# 0414380 17709932 3
# 0414380 1988202611 4
# 0414380 2169620084 4
# 0414380 2671739255 5
# 0414380 2158085241 3
# 0414380 2169855356 3
# 0414380 2403907455 5
# 0414380 1492131973 3
# 0414380 1984107911 4
# 0414380 2096070028 4
# 0414380 2155356560 3
# 0414380 1509226144 3
# 0414380 2274446241 4
# 0414380 2100832675 3
# 0414380 1865338280 3
# 0414380 2050035370 4
# 0414380 2122441390 3
# 0414380 2017243320 7
# 0414380 2148027834 3
# 0414380 2024319164 3
# 0414380 2769728700 3
# 0414380 2114005694 4
# 0414380 1708580544 5
# 0414380 1964056524 3
# 0414380 1973080017 3
# 0414380 2145646037 3
# 0414380 2156136663 3
# 0414380 2093230809 5
# 0414380 1972445403 4
# 0414380 2808198108 7
# 0414380 2115939037 4
# 0414380 2090150367 3
# 0414380 2155675108 3
# 0414380 2052936169 5
# 0414380 1977050089 4
# 0414380 154741484 3
# 0414380 2182050287 3
# 0414380 2101464304 4
# 0414380 2060267256 4
# 0414482 24033664 2
# 0414482 2123209634 6
# 0414482 2079254915 4
# 0414482 1506961381 4
# 0414482 2071198182 2
# 0414482 1586062708 2
# 0414482 1524642076 2
# 0414482 2166839519 2
# 0414567 40920192 4
# 0414567 1567730817 3
# 0414567 182378115 4
# 0414567 2053219460 3
# 0414567 1490628103 4
# 0414567 2169052808 8
# 0414567 1592547468 3
# 0414567 2056050966 4
# 0414567 2534579609 4
# 0414567 2532776093 3
# 0414567 2090136992 3
# 0414567 2130610992 3
# 0414567 2070920242 5
# 0414567 2502260019 5
# 0414567 2064171700 4
# 0414567 59141174 3
# 0414567 1513201335 3
# 0414567 2090083512 3
# 0414567 249175354 3
# 0414567 2168978747 4
# 0414567 2122194364 3
# 0414567 2165134527 3
# 0414567 2021278148 4
# 0414567 2169461572 5
# 0414567 2132536267 3
# 0414567 2121659340 3
# 0414567 2136636236 3
# 0414567 2075511629 3
# 0414567 2022565586 4
# 0414567 2134753879 4
# 0414567 1990715867 3
# 0414567 2046623451 3
# 0414567 1529847395 3
# 0414567 2120505316 3
# 0414567 2132769004 4
# 0414567 2683415663 3
# 0414567 1975784309 4
# 0414567 1530251775 4
# 0414630 111126860 3
# 0414630 2257244765 3
# 0414630 2004774622 5
# 0414630 2166852192 3
# 0414630 2100898470 4
# 0414630 206774317 3
# 0414630 1796890415 3
# 0414630 2029515381 3
# 0414630 1983685815 5
# 0414630 195611835 3
# 0414710 2121429546 4
# 0414710 2141707706 4
# 0414710 2101432859 4
# 0414710 2614477022 4
# 0414763 1984710256 3
# 0414791 2118391168 2
# 0414791 2149475204 3
# 0414791 2099873680 2
# 0414791 2037908498 2
# 0414791 2083078747 4
# 0414791 2152746211 2
# 0414791 2083893290 4
# 0414791 167493099 2
# 0414791 2127127793 4
# 0414791 1481543858 5
# 0414791 2089369722 3
# 0414976 2790864000 9
# 0414976 2027281090 2
# 0414976 1957031268 5
# 0414976 2146354725 3
# 0414976 995681285 6
# 0414976 1569159205 3
# 0414976 2118547567 3
# 0414976 2109737845 6
# 0414976 2152538582 5
# 0414976 2079004857 3
# 0414976 2134625787 2
# 0414981 2111693152 5
# 0414981 2129088452 5
# 0414981 2114674735 3
# 0414981 2150153790 3
# 0415195 188145618 5
# 0415257 2777524230 3
# 0415257 2617342730 3
# 0415257 37570443 4
# 0415257 2004188181 5
# 0415257 2339225884 3
# 0415257 1988615847 3
# 0415257 2028980140 3
# 0415257 50675760 2
# 0415257 2803875894 4
# 0415257 2086219721 4
# 0415257 205402838 3
# 0415257 2073566426 3
# 0415257 2043636189 3
# 0415257 279525992 4
# 0415257 2001995757 4
# 0415257 2125252087 4
# 0415257 72456441 3
# 0415257 2163133050 4
# 0415257 2075536383 3
# 0415865 2169384404 6
# 0415865 2119187236 4
# 0418165 2130622458 5
# 0423039 2156375169 5
# 0423039 2131220353 3
# 0423039 1642384772 3
# 0423039 2105341447 4
# 0423039 2097636360 3
# 0423039 2107120136 4
# 0423039 201269517 4
# 0423039 30485839 2
# 0423039 2087661010 4
# 0423039 2097560155 4
# 0423039 2109584604 4
# 0423039 2155760164 5
# 0423039 2109084388 3
# 0423039 2091174269 2
# 0423039 2162111272 3
# 0423039 2129046573 4
# 0423039 2121654015 4
# 0423039 2117509237 5
# 0423039 1675944701 2
# 0423039 2118521279 5
# 0423253 2133581806 6
# 0426557 2008287329 5
# 0426557 2047967940 6
# 0426557 2079883374 9
# 0426627 2141328720 5
# 0426627 73935682 5
# 0426627 122382148 4
# 0426627 1731807204 4
# 0426627 2168053878 7
# 0426627 2152563917 4
# 0426627 2413527566 3
# 0426627 2105020570 8
# 0426674 2167666016 3
# 0426674 1503804099 4
# 0426674 109857240 3
# 0426674 2258716650 3
# 0426674 23833741 4
# 0426674 190243666 3
# 0426674 2017380760 2
# 0426674 2770520409 3
# 0427695 2135558784 3
# 0427695 2057680271 5
# 0427695 2131553043 4
# 0427695 2029076504 4
# 0427695 2037316890 7
# 0427695 1606346782 3
# 0427695 2793342626 4
# 0427695 2040570658 5
# 0427695 2766956330 6
# 0427695 2221563957 17
# 0427695 2114897591 5
# 0427695 2143143237 5
# 0427695 2109859915 3
# 0427695 2090808267 3
# 0427695 2114787411 4
# 0427695 1550110557 3
# 0427695 2886982240 4
# 0427695 2326059109 10
# 0427695 2767932261 6
# 0427695 2126809447 3
# 0427695 2000376553 5
# 0427695 2081141489 5
# 0427695 2132217332 5
# 0428427 1499623512 2
# 0428427 1546207031 3
# 0429154 2086112425 3
# 0429154 2555121777 4
# 0429154 2090561681 4
# 0429154 2148855255 4
# 0429154 2152203581 3
# 0429154 2115143695 4
# 0429228 2168058952 4
# 0429228 267918989 3
# 0429228 2545815118 2
# 0429228 2164580880 2
# 0429228 2044657527 4
# 0429228 2129010335 4
# 0429364 2119985794 9
# 0429364 2188800392 4
# 0429364 1574648717 4
# 0429364 1856971918 7
# 0429364 2107903248 4
# 0429364 2136209041 7
# 0429364 1986648850 7
# 0429364 1964402839 3
# 0429364 1582991129 11
# 0429364 2612341273 3
# 0429364 2084334238 6
# 0429364 1586272167 11
# 0429364 2102766632 3
# 0429364 1556578092 7
# 0429364 2584247852 11
# 0429364 1566166064 5
# 0429364 1741087670 8
# 0429364 2144588087 10
# 0429364 1498464828 8
# 0429364 1978879806 3
# 0429364 2549822271 5
# 0429364 2372592707 3
# 0429364 1566363079 4
# 0429364 55875535 7
# 0429364 1760892502 10
# 0429364 2056797271 9
# 0429364 1523665759 11
# 0429364 2613541219 4
# 0429364 1731154916 3
# 0429364 1989377254 5
# 0429364 2152725350 3
# 0429364 2066636904 4
# 0429364 1586510703 4
# 0429364 1811793013 8
# 0429364 2085721207 5
# 0429364 2612077305 8
# 0429364 1543105787 4
# 0429631 2158684546 6
# 0429631 2135358850 7
# 0429631 2051260038 3
# 0429631 1668025881 5
# 0429631 1602012315 8
# 0429631 2669083052 5
# 0429631 15135546 3
# 0429631 2116981307 5
# 0429631 2011443263 6
# 0429631 2120326208 8
# 0429631 2104283712 7
# 0429631 2541640542 5
# 0429631 2083722722 7
# 0429631 2154614244 5
# 0429631 2155597158 6
# 0429631 2165320173 7
# 0429631 2492693649 7
# 0429631 182961560 3
# 0429631 304628903 3
# 0429631 259078460 3
# 0429631 2626537156 7
# 0429631 224173253 3
# 0429631 2140834004 5
# 0429631 2106537813 8
# 0429631 2123917655 8
# 0429631 2153025112 6
# 0429631 2182346076 7
# 0429631 2141964508 7
# 0429631 2047379549 7
# 0429631 72954339 3
# 0429631 2156811502 7
# 0429631 331627382 3
# 0429631 266808702 3
# 0429640 1988020221 2
# 0429640 1884932909 3
# 0429711 2594097826 6
# 0429711 2010802738 9
# 0429711 2102102439 14
# 0429711 2132877867 5
# 0429711 2162270846 5
# 0429766 2320445952 3
# 0429766 2165922306 5
# 0429766 2115269638 3
# 0429766 2027425799 5
# 0429766 2036072461 6
# 0429766 2800261646 3
# 0429766 1871783442 4
# 0429766 1604098070 4
# 0429766 2802187291 3
# 0429766 2101930528 4
# 0429766 2126669347 3
# 0429766 2103376423 4
# 0429766 2057707063 4
# 0429766 1585065018 6
# 0429766 2022046782 4
# 0429766 2141434434 3
# 0429766 2130520143 3
# 0429766 2111577171 4
# 0429766 2065625689 5
# 0429766 1607139420 3
# 0429766 2164713056 3
# 0429766 1607695459 4
# 0429766 2427253863 4
# 0429766 1993695337 5
# 0429766 2154916972 5
# 0429766 2148481133 3
# 0429766 1564485747 5
# 0429766 2014022260 4
# 0429766 2159024757 4
# 0429766 2170438773 4
# 0429766 1973094521 6
# 0429766 2161031811 3
# 0429766 2116320387 3
# 0429766 2121500293 4
# 0429766 2021320327 3
# 0429766 2124674185 4
# 0429766 2021095575 3
# 0429766 2160026778 4
# 0429766 1513723553 5
# 0429766 2161959597 3
# 0429766 2163783855 4
# 0429766 2041597620 6
# 0429766 1550816954 3
# 0429766 2141088957 3
# 0429766 2032429251 3
# 0429766 2157668551 5
# 0429766 2024179912 5
# 0429766 1593944776 3
# 0429766 2027478729 3
# 0429766 2046365389 4
# 0429766 2104035023 4
# 0429766 236798679 4
# 0429766 1700403417 6
# 0429766 1562282729 3
# 0429766 2141625582 6
# 0429766 2123582706 3
# 0429766 2163525376 3
# 0429766 2074480906 3
# 0429766 2107593492 5
# 0429766 2334125845 3
# 0429766 2146081558 3
# 0429766 2114176791 4
# 0429766 2109570325 4
# 0429766 2117768990 4
# 0429766 2905448735 3
# 0429766 2132328228 3
# 0429766 2115877157 3
# 0429766 2100695852 3
# 0429766 2781391663 4
# 0429766 2117694769 3
# 0429766 1495245622 4
# 0429766 2758615866 3
# 0429766 2150395713 5
# 0429766 2166763847 5
# 0429766 1563201869 4
# 0429766 2781664087 8
# 0429766 2034125661 5
# 0429766 2131477866 5
# 0429766 2111597937 5
# 0429766 2011797893 3
# 0429766 1858417033 3
# 0429766 2170009484 4
# 0429766 2139885456 3
# 0429766 2169046435 3
# 0429766 2164786095 3
# 0429766 2146774978 4
# 0429766 2114168262 3
# 0429766 2125626824 4
# 0429766 1564170199 5
# 0429766 2041305048 3
# 0429766 2163817444 3
# 0429766 1800449509 3
# 0429766 2157683703 4
# 0429766 2155352570 4
# 0429766 1860683259 3
# 0429766 2128287228 4
# 0429766 2587566099 9
# 0429766 1964754973 3
# 0429766 2148347940 3
# 0429766 1656012331 4
# 0429766 2144414365 4
# 0429766 2128157854 3
# 0429766 2083980970 3
# 0429766 2018097393 4
# 0429766 2159533852 3
# 0429766 2096636711 5
# 0429766 1970997128 7
# 0429766 2170213768 3
# 0429766 2091434892 3
# 0429766 1506245543 4
# 0429766 2053903311 4
# 0429836 2091815328 7
# 0429836 1490720341 5
# 0429836 98718822 3
# 0429836 15181062 3
# 0429836 2496153388 5
# 0429836 2340843501 3
# 0429930 2102785080 4
# 0429930 2099679924 5
# 0429930 2185692448 5
# 0429930 2137509664 3
# 0429930 2157067268 3
# 0429930 2066816868 5
# 0429930 2147987109 5
# 0429930 2084446759 3
# 0429930 2068870507 4
# 0429930 2142908374 5
# 0429930 2076372184 5
# 0429930 2106231834 5
# 0429930 2127877371 4
# 0429930 2732633021 4
# 0429948 1820628193 4
# 0429948 1984814758 4
# 0429948 2251141322 3
# 0429948 2120393517 4
# 0429948 2412815634 4
# 0429948 2105461974 4
# 0429948 1501350719 3
# 0430271 2170809188 4
# 0430271 2160161493 4
# 0430271 2112935288 4
# 0430271 2119795353 4
# 0430271 2138342539 4
# 0430303 1969347587 3
# 0430303 2064173066 4
# 0430303 2576312337 3
# 0430303 1583639061 4
# 0430303 2613089305 3
# 0430303 2577018399 4
# 0430303 2144194596 4
# 0430303 1546447935 3
# 0430303 173524545 3
# 0430303 2584617561 3
# 0430303 1989279326 4
# 0430303 2187421812 2
# 0430303 2010422928 3
# 0430303 2406015634 3
# 0430303 2156103833 4
# 0430303 2903395998 3
# 0430303 2684996256 3
# 0430303 61758119 3
# 0430303 2036140203 4
# 0430303 2404905139 3
# 0430303 2728544954 3
# 0430303 2188704965 3
# 0430303 2563934921 3
# 0430303 1980122825 3
# 0430303 2045450443 3
# 0430303 2729349341 3
# 0430303 2117449950 6
# 0430303 2748058847 3
# 0430303 1558568167 3
# 0430303 2274674922 3
# 0430303 144806122 4
# 0430303 2397423854 3
# 0430303 2131869937 3
# 0430303 2145413874 3
# 0430303 2466770681 3
# 0430303 2029424893 4
# 0430303 2009385725 3
# 0430303 566466817 3
# 0430303 2174327560 6
# 0430303 2189336331 4
# 0430303 201942294 3
# 0430303 151997209 3
# 0430303 2296684318 3
# 0430303 2185240358 4
# 0430303 15341867 4
# 0430303 118936888 3
# 0430303 1978609982 3
# 0430303 2794879295 6
# 0430303 21246281 5
# 0430303 2593555287 3
# 0430303 1576240472 3
# 0430303 2590454106 6
# 0430303 145109340 4
# 0430303 2083153244 3
# 0430303 2017107296 4
# 0430303 89811811 3
# 0430303 2758966628 3
# 0430303 2805454182 5
# 0430303 2001481583 3
# 0430303 1789957497 4
# 0430303 2885648761 3
# 0430303 1971994493 4
# 0430303 2115398528 4
# 0430303 2394764681 3
# 0430303 161604504 4
# 0430303 2785455005 3
# 0430303 2574333341 3
# 0430303 37421488 3
# 0430303 15400374 4
# 0430303 1996552124 3
# 0430303 2131207107 4
# 0430303 1489114055 4
# 0430303 2605148104 3
# 0430303 1560315852 3
# 0430303 2253607376 3
# 0430303 2187525078 4
# 0430303 2016506327 3
# 0430303 2109864930 3
# 0430303 2481733604 3
# 0430303 1487388135 4
# 0430303 256044014 4
# 0430303 2187889135 3
# 0430303 2612612598 5
# 0430303 2815464439 4
# 0430303 2020701179 4
# 0430303 141513725 3
# 0430303 2100370943 4
# 0430304 2318581762 6
# 0430304 1967656199 3
# 0430304 64156040 4
# 0430304 2139542924 6
# 0430304 2545555219 5
# 0430304 267893269 2
# 0430304 2049685271 4
# 0430304 2103446296 11
# 0430304 2170207772 4
# 0430304 1577637277 3
# 0430304 2115819049 6
# 0430304 2536261164 3
# 0430304 1865477295 3
# 0430304 1985454260 4
# 0430304 2063594678 3
# 0430304 1587548215 10
# 0430304 2148009787 10
# 0430304 2155141181 3
# 0430304 124329667 3
# 0430304 1967949770 4
# 0430304 37616203 4
# 0430304 2030650827 3
# 0430304 288351440 2
# 0430304 2098981715 3
# 0430304 2170771030 4
# 0430304 2003371734 7
# 0430304 184603478 10
# 0430304 2155416924 3
# 0430304 2148662748 4
# 0430304 45500642 3
# 0430304 1509420901 3
# 0430304 2098334439 3
# 0430304 1971529969 4
# 0430304 2119127927 4
# 0430304 2093933564 3
# 0430304 1487361149 4
# 0430304 2218485375 6
# 0430318 2487697280 5
# 0430318 2073396684 3
# 0430318 2023465037 3
# 0430318 2503241677 6
# 0430318 2098937825 2
# 0430318 1996516136 2
# 0430318 1583675816 4
# 0430318 227878698 3
# 0430318 2075080680 6
# 0430318 2480490034 6
# 0430318 2011721139 5
# 0430318 1975066611 3
# 0430318 2472324277 6
# 0430318 588710710 5
# 0430402 2026039808 3
# 0430402 1856014338 3
# 0430402 1508325896 5
# 0430402 2106465551 4
# 0430402 2169689872 4
# 0430402 2478074421 5
# 0430402 1020741688 3
# 0430402 2116700985 3
# 0430402 157664586 3
# 0430402 1978184781 3
# 0430402 315494487 3
# 0430402 84822105 4
# 0430402 2108433244 5
# 0430402 1563444064 4
# 0430402 2164111201 3
# 0430402 20023138 5
# 0430402 2260906342 4
# 0430402 2162614120 4
# 0430402 1631096428 3
# 0430402 203848308 3
# 0430402 1596299124 3
# 0430402 15695225 3
# 0430402 958554746 3
# 0430402 2124912507 4
# 0430402 1492312449 3
# 0430402 2158850947 3
# 0430402 1518480520 3
# 0430402 1929645967 3
# 0430402 1504714130 4
# 0430402 2025181331 5
# 0430402 230731157 4
# 0430402 2135333014 4
# 0430402 2612623515 4
# 0430402 1503027868 3
# 0430402 1688672670 3
# 0430402 2096521379 5
# 0430402 2611477166 3
# 0430402 63760559 3
# 0430402 1564955056 3
# 0430402 2027494324 3
# 0430402 124597432 3
# 0430402 2023417025 4
# 0430402 1483198150 3
# 0430402 2029435358 4
# 0430402 2139257570 4
# 0430402 121159909 3
# 0430402 2113672679 5
# 0430402 1539419373 3
# 0430402 2407665 3
# 0430402 1588969459 3
# 0430477 1972699782 5
# 0430477 2121138187 4
# 0430477 2163226123 5
# 0430477 1507576981 8
# 0430477 2212757 3
# 0430477 2113167642 4
# 0430477 21427492 3
# 0430477 2149684006 4
# 0430477 2407530542 3
# 0430477 1546773937 5
# 0430477 308775487 4
# 0430477 2037683905 5
# 0430477 2473574723 3
# 0430477 1530120774 5
# 0430477 1961152966 4
# 0430477 1607416013 3
# 0430477 2406255059 3
# 0430477 1542053855 3
# 0430477 2335969121 3
# 0430477 2147943784 4
# 0430477 1734019305 7
# 0430477 136570475 3
# 0430477 2150883821 4
# 0430477 970438637 4
# 0430477 2153527920 6
# 0430477 2155121521 3
# 0430477 11819637 6
# 0430477 69245817 8
# 0430477 2164996477 5
# 0430477 2310999551 4
# 0430487 2142507341 3
# 0430487 2105598683 5
# 0430487 2166369424 5
# 0430487 2148891604 4
# 0430510 2106447363 3
# 0430510 147895047 4
# 0430510 1910816777 7
# 0430510 2069984009 5
# 0430510 2086838666 7
# 0430510 2168674192 5
# 0430510 1508521621 7
# 0430510 2099323800 6
# 0430510 1585471902 5
# 0430510 2004484769 4
# 0430510 2147740195 4
# 0430510 1620900388 5
# 0430510 1569757987 5
# 0430510 1577165222 5
# 0430510 2293878697 7
# 0430510 2274235828 3
# 0430510 2126789306 5
# 0430510 1770174463 5
# 0430510 2128352062 7
# 0430510 1698117324 5
# 0430510 2068983118 6
# 0430510 2038345682 5
# 0430510 1850597240 6
# 0430510 2022582229 5
# 0430510 1487382749 3
# 0430510 2294423262 6
# 0430510 2125264097 4
# 0430510 1985727586 4
# 0430510 2154753892 4
# 0430510 115127268 6
# 0430510 1726660068 3
# 0430510 138229359 4
# 0430510 186249712 7
# 0430510 2139359217 5
# 0430510 118129268 4
# 0430510 1540902136 3
# 0430510 1966383354 5
# 0430510 1827755647 5
# 0430781 1975303279 6
# 0430781 2089732905 10
# 0430781 2040933249 4
# 0430781 1995297249 12
# 0430849 2154937603 4
# 0430849 2017619076 5
# 0430849 2584609412 7
# 0430849 2121573131 3
# 0430849 2105401484 7
# 0430849 850972942 4
# 0430849 1540575502 4
# 0430849 829689105 7
# 0430849 2116792850 3
# 0430849 2056536338 4
# 0430849 1553603221 4
# 0430849 1529661724 5
# 0430849 2903170972 7
# 0430849 1620667300 5
# 0430849 1528159271 3
# 0430849 2085562535 14
# 0430849 2000242599 3
# 0430849 2784219559 6
# 0430849 2734499628 7
# 0430849 2099898669 14
# 0430849 2162649143 3
# 0430849 1600867257 7
# 0430849 2064761790 7
# 0430849 2174643652 9
# 0430849 2405711304 7
# 0430849 2134710090 6
# 0430849 2169705039 8
# 0430849 2030754129 6
# 0430849 2180211925 5
# 0430849 2178552022 10
# 0430849 2150122711 6
# 0430849 53912917 4
# 0430849 2024503255 6
# 0430849 2074574297 8
# 0430849 2104947808 8
# 0430849 2069358561 7
# 0430849 2898845797 8
# 0430849 2137457770 3
# 0430849 2766893803 7
# 0430849 1587165042 7
# 0430885 87392896 4
# 0430885 2697326336 3
# 0430885 2101227906 4
# 0430885 2414939786 5
# 0430885 2038086285 5
# 0430885 2090657187 3
# 0430885 2144590628 7
# 0430885 2119359654 4
# 0430885 2111419948 5
# 0430885 2057916077 5
# 0430885 2147406125 4
# 0430885 2092817587 6
# 0430885 2020715003 3
# 0430885 2083088699 5
# 0430885 1507367612 4
# 0430885 2056407621 3
# 0430885 2147643333 3
# 0430885 2001865298 5
# 0430885 125398996 4
# 0430885 2159776727 4
# 0430885 2120975075 4
# 0430885 2102647396 4
# 0430885 2135487204 4
# 0430885 2417504484 5
# 0430885 1964780259 4
# 0430885 2047295717 5
# 0430885 2165692269 4
# 0430885 2103810676 5
# 0430885 82567029 5
# 0430885 2158804859 5
# 0430994 2275710340 5
# 0430994 2479722630 5
# 0430994 2077397644 4
# 0430994 2140957972 4
# 0430994 2069986075 3
# 0430994 1565438236 3
# 0430994 2605000607 5
# 0430994 2115347616 4
# 0430994 1976957990 3
# 0430994 2893897254 5
# 0430994 2101827111 4
# 0430994 2126225192 4
# 0430994 2407892906 4
# 0430994 2107115563 4
# 0430994 2016785840 3
# 0430994 2401502514 4
# 0430994 1995915698 4
# 0430994 2020228538 4
# 0430994 2006214331 3
# 0430994 2126697916 3
# 0430994 1487949759 5
# 0430994 1584754763 4
# 0430994 2609779791 4
# 0430994 2131824121 4
# 0430994 2798601084 4
# 0430994 2042287357 4
# 0431024 1972561930 3
# 0431024 2026233866 3
# 0431024 2125781780 7
# 0431024 2136956182 4
# 0431024 2068535580 3
# 0431024 2128343069 3
# 0431024 2034964509 4
# 0431024 2076758047 4
# 0431024 2166561568 5
# 0431024 1487328802 4
# 0431024 2150178085 4
# 0431024 2116098857 4
# 0431024 2173830187 4
# 0431024 2014184493 4
# 0431024 2119603765 4
# 0431024 2764517956 5
# 0431024 2023461447 5
# 0431024 2087021397 5
# 0431024 2070887005 4
# 0431024 2475973217 4
# 0431024 2062033254 3
# 0431024 1997288808 4
# 0431024 2500775529 5
# 0431024 1985720430 4
# 0431024 2115979379 4
# 0431024 1897460085 6
# 0431024 2060349562 4
# 0431024 2499623562 4
# 0431024 1628762262 5
# 0431024 1906368150 7
# 0431024 2535790239 3
# 0431024 1502833575 4
# 0431024 2791753646 4
# 0431024 1993814448 5
# 0431024 1983650490 7
# 0431024 2490590405 7
# 0431024 2002750662 4
# 0431024 1990578378 3
# 0431024 1995877069 6
# 0431024 2178066639 5
# 0431024 2111487185 4
# 0431024 2171146967 3
# 0431024 2187006936 5
# 0431024 2078602456 4
# 0431024 1518677976 4
# 0431024 2503026143 3
# 0431024 2025312995 3
# 0431024 2148455651 4
# 0431024 2085780709 6
# 0431024 2151236582 5
# 0431024 2112999913 4
# 0431024 2151336180 4
# 0431030 2063720962 4
# 0431030 2570519564 5
# 0431030 2241607186 9
# 0431030 2123100691 3
# 0431030 2063540785 7
# 0431030 1990729778 7
# 0431030 2112692787 9
# 0431030 2021637684 5
# 0431030 2090598456 4
# 0431030 2105416264 7
# 0431030 1996965968 5
# 0431030 2805761617 7
# 0431030 2068752469 3
# 0431030 1573089367 4
# 0431030 1999355997 4
# 0431030 2889084514 5
# 0431030 2278760039 8
# 0431030 2021746803 3
# 0431030 1501813877 3
# 0431030 2081312892 5
# 0431030 2141585031 9
# 0431030 2167591570 3
# 0431030 2168155808 5
# 0431030 1971649192 7
# 0431030 1996160681 6
# 0431030 1528966325 3
# 0431030 75760822 3
# 0431030 2123260089 5
# 0431030 2174232782 7
# 0431030 2100008148 3
# 0431030 2049310936 5
# 0431030 2148435166 3
# 0431030 2017680106 3
# 0431030 2268042477 5
# 0431030 2763130607 8
# 0431030 2106726641 4
# 0431030 2399669489 4
# 0431030 2742962432 8
# 0431030 2177594625 7
# 0431030 186948357 7
# 0431030 2403460359 4
# 0431030 2568219399 7
# 0431030 2092425487 8
# 0431030 2568731922 4
# 0431030 33021721 5
# 0431030 51208988 3
# 0431030 1982991648 6
# 0431030 2169676578 4
# 0431030 1698175267 7
# 0431030 1608814893 6
# 0431030 1570631982 7
# 0431030 2397265210 7
# 0431030 976710 5
# 0431030 1601787207 4
# 0431030 2024843086 3
# 0431030 2046260559 9
# 0431030 2117862225 5
# 0431030 2000889179 6
# 0431030 1537926502 9
# 0431030 2519911274 7
# 0431030 2071867759 5
# 0431030 1816309617 7
# 0431030 2055196529 7
# 0431030 1658640257 5
# 0431030 2735878530 7
# 0431030 2525086081 3
# 0431030 2294021512 7
# 0431030 2267734922 5
# 0431030 2212293515 3
# 0431030 1537994124 5
# 0431030 2159661471 5
# 0431030 1661438368 4
# 0431030 1535557537 3
# 0431030 1966692774 5
# 0431030 2337478058 7
# 0431030 2033724843 7
# 0431030 2124956076 7
# 0431030 2440915886 7
# 0431030 2749870 4
# 0431030 2005353392 9
# 0431030 1633362871 3
# 0431030 2004171193 5
# 0431030 2018746304 5
# 0431030 54257602 3
# 0431030 2093151180 9
# 0431030 2403028947 9
# 0431030 2296258528 8
# 0431030 1973102563 3
# 0431030 2118063590 7
# 0431030 2078838257 5
# 0431030 2126353399 3
# 0431030 2137196537 4
# 0431030 2188787706 3
# 0431030 339469309 3
# 0431031 2239757569 8
# 0431031 2107888069 4
# 0431031 2572609801 3
# 0431031 2171254602 3
# 0431031 2124901934 5
# 0431031 1721925425 6
# 0431031 1499481682 5
# 0431031 2127475735 3
# 0431031 143149112 3
# 0431059 1567707649 3
# 0431059 2136529925 4
# 0431059 1970275339 4
# 0431059 2724495629 2
# 0431059 1548716816 4
# 0431059 2615147282 3
# 0431059 246329109 4
# 0431059 2055719721 3
# 0431059 2590087982 4
# 0431059 2615488562 4
# 0431059 2399370290 3
# 0431059 1856729396 3
# 0431059 2009606709 3
# 0431059 2396825143 3
# 0431059 1843221822 4
# 0431059 2397480006 4
# 0431059 1563931474 2
# 0431059 2292697683 4
# 0431059 2480160089 3
# 0431059 2460485210 3
# 0431059 2103113565 3
# 0431059 2177967966 4
# 0431059 2403261537 3
# 0431059 2407296372 5
# 0431059 1982859903 3
# 0431059 1538604683 4
# 0431059 2398161807 3
# 0431059 97534101 4
# 0431059 2615474069 6
# 0431059 1983436960 3
# 0431059 1884233127 6
# 0431059 2045008295 3
# 0431059 1974882476 6
# 0431059 2614201774 3
# 0431059 2018977199 2
# 0431059 1559680689 3
# 0431059 1538993357 4
# 0431059 1590869460 3
# 0431059 1571482849 3
# 0431059 1992471277 4
# 0431059 2039954414 2
# 0431059 39428341 3
# 0431059 1557131514 3
# 0431088 2160687621 2
# 0431088 123782344 3
# 0431088 2145317006 3
# 0431088 2037801169 3
# 0431088 1925162134 3
# 0431088 44256860 2
# 0431088 2121485091 3
# 0431088 2152452645 3
# 0431088 2161357868 2
# 0431088 2168058733 3
# 0431088 2122492335 3
# 0431088 2120988089 3
# 0431150 2147056688 3
# 0431150 2097224497 4
# 0431166 1641967812 5
# 0431166 2009503044 5
# 0431166 2398826694 3
# 0431166 2112104588 4
# 0431166 2166128845 9
# 0431166 2807479512 2
# 0431166 2162068889 2
# 0431166 2057144282 4
# 0431166 1771237788 2
# 0431166 1620029983 2
# 0431166 2072540768 3
# 0431166 62621028 6
# 0431166 50242663 4
# 0431166 2143218482 3
# 0431166 53713460 3
# 0431166 58189109 3
# 0431166 2142041076 2
# 0431166 1987531579 3
# 0432063 2096851334 2
# 0432063 2108101655 2
# 0432063 2089049622 2
# 0432098 2184926087 3
# 0432098 1990676938 3
# 0432098 2405650127 4
# 0432098 1993380752 3
# 0432098 2111918617 4
# 0432098 1592458204 2
# 0432098 2127868702 3
# 0432098 2606781857 2
# 0432098 13113963 5
# 0432098 2132132335 4
# 0432098 2162491184 7
# 0432098 1584110319 2
# 0432098 2106079922 3
# 0432098 2140960822 3
# 0434410 2017022788 2
# 0434410 2739873551 2
# 0434410 1964728727 2
# 0434410 2085376250 3
# 0434996 2139929478 7
# 0434996 2125832781 5
# 0434996 2088632464 4
# 0434996 2149680913 4
# 0434996 1610423063 2
# 0434996 2114683223 6
# 0434996 2120514843 7
# 0434996 2043469923 3
# 0434996 2171241196 5
# 0434996 1527145454 5
# 0434996 2139905147 6
# 0435065 2318581762 6
# 0435065 1967656199 3
# 0435065 64156040 4
# 0435065 2139542924 6
# 0435065 2545555219 5
# 0435065 267893269 2
# 0435065 2049685271 4
# 0435065 2103446296 11
# 0435065 2170207772 4
# 0435065 1577637277 3
# 0435065 2115819049 6
# 0435065 2536261164 3
# 0435065 1865477295 3
# 0435065 1985454260 4
# 0435065 2063594678 3
# 0435065 1587548215 10
# 0435065 2148009787 10
# 0435065 2155141181 3
# 0435065 124329667 3
# 0435065 1967949770 4
# 0435065 37616203 4
# 0435065 2030650827 3
# 0435065 288351440 2
# 0435065 2098981715 3
# 0435065 2170771030 4
# 0435065 2003371734 7
# 0435065 184603478 10
# 0435065 2155416924 3
# 0435065 2148662748 4
# 0435065 45500642 3
# 0435065 1509420901 3
# 0435065 2098334439 3
# 0435065 1971529969 4
# 0435065 2119127927 4
# 0435065 2093933564 3
# 0435065 1487361149 4
# 0435065 2218485375 6
# 0435111 88752697 4
# 0435111 2104398282 3
# 0435111 2135289087 4
# 0435247 1991357351 3
# 0435247 2037415870 3
# 0435247 2048855920 4
# 0435247 2123492772 5
# 0435272 1505301880 5
# 0435272 2171496711 3
# 0435272 2079156232 3
# 0435272 1978826249 3
# 0435272 2755577992 9
# 0435272 1496706313 4
# 0435272 2102589200 11
# 0435272 1885778852 4
# 0435272 2012253736 3
# 0435272 2060311081 6
# 0435272 2519068331 3
# 0435272 2142646704 3
# 0435272 2044183862 5
# 0435272 2346843068 3
# 0435272 2284876990 3
# 0435272 6147067 4
# 0435272 2005291211 3
# 0435272 1763716939 4
# 0435272 2203221455 2
# 0435272 2151861976 3
# 0435272 2112326623 3
# 0435272 47395808 3
# 0435272 2008904160 3
# 0435272 2187965929 4
# 0435272 99947114 5
# 0435272 2096254570 3
# 0435272 2107836909 5
# 0435272 2132405999 2
# 0435272 2301719024 3
# 0435272 1895806193 3
# 0435272 2292379254 3
# 0435272 1905794424 3
# 0435272 2064525435 3
# 0435272 1968323964 3
# 0435272 1880209405 7
# 0435272 2141760382 3
# 0435303 2143756451 3
# 0435303 2105413189 4
# 0435303 1710235590 3
# 0435303 2089770759 3
# 0435303 2158794280 3
# 0435303 1899342455 3
# 0435303 2153450930 3
# 0435303 2077719959 3
# 0435303 1919494327 3
# 0435303 2293342462 3
# 0435303 2135647263 3
# 0435303 2246978295 3
# 0435303 2136848335 4
# 0435505 2047977378 3
# 0435505 2126449801 4
# 0435505 2091072140 4
# 0435505 2145967148 3
# 0435505 2131894414 4
# 0435505 1589949070 5
# 0435505 2112759983 4
# 0435505 2017751697 4
# 0435505 2138325452 3
# 0435505 2169896918 4
# 0435505 1600565850 4
# 0435505 2129783551 3
# 0435517 2269386376 6
# 0435517 2144017041 3
# 0435517 2122734354 3
# 0435517 2081164438 5
# 0435517 2103278235 3
# 0435517 2130937250 3
# 0435517 2134385059 6
# 0435517 1807350691 7
# 0435517 2135505702 3
# 0435517 2054094122 5
# 0435517 2769257392 3
# 0435517 2380430262 5
# 0435517 1798143162 2
# 0435517 2151337919 4
# 0435517 2109824073 4
# 0435517 1984309718 3
# 0435517 2137814624 5
# 0435517 2401463395 3
# 0435517 1512219752 9
# 0435517 2107213416 3
# 0435517 2127747945 3
# 0435517 2159013099 3
# 0435517 2341081982 5
# 0437810 126942859 4
# 0437810 2148317584 3
# 0437810 1986518033 6
# 0437810 1507900435 7
# 0437810 2152526229 5
# 0437810 2091476130 5
# 0437810 1750383522 30
# 0437810 2160723894 20
# 0437810 2111451064 5
# 0437810 11839563 3
# 0437810 95466700 3
# 0437810 1987713100 7
# 0437810 259012431 3
# 0437810 179514708 3
# 0437810 1980135511 7
# 0437810 262732504 3
# 0437810 1510894298 4
# 0437810 2150511069 3
# 0437810 1570802937 8
# 0437810 2107178875 3
# 0437810 2028141695 4
# 0438263 2164271106 3
# 0438263 2058241667 2
# 0438263 2133752580 4
# 0438263 2133100549 4
# 0438263 43414920 2
# 0438263 2123024267 3
# 0438263 1565165333 2
# 0438263 1570361750 4
# 0438263 2110257442 9
# 0438263 2093667746 3
# 0438263 2112364709 2
# 0438263 2097275303 4
# 0438263 1482257577 4
# 0438263 2146799402 4
# 0438263 2126826034 6
# 0438263 1948980021 12
# 0438263 2158698938 2
# 0438263 2112331197 7
# 0438263 2074730180 9
# 0438263 2095939654 4
# 0438263 2027727943 5
# 0438263 2043166282 4
# 0438263 2121067221 8
# 0438263 2145105629 7
# 0438263 2099497311 3
# 0438263 2120411746 2
# 0438263 201021051 4
# 0444417 2113948228 3
# 0453456 2091095042 9
# 0453456 1994895875 4
# 0453456 1989546758 3
# 0453456 2125827346 4
# 0453456 2842958868 5
# 0453456 1992094230 4
# 0453456 2792866074 4
# 0453456 2063933469 5
# 0453456 2461828133 4
# 0453456 1974122280 4
# 0453456 2124062510 4
# 0453456 1978517039 5
# 0453456 2163178035 4
# 0453456 179490361 4
# 0453456 106214459 4
# 0453456 2044207931 4
# 0453456 1973441086 5
# 0453456 2904302655 7
# 0453456 2054376514 4
# 0453456 2030814277 4
# 0453456 2112909893 3
# 0453456 1992802125 5
# 0453456 2082335822 4
# 0453456 2010292045 4
# 0453456 2128793168 4
# 0453456 2591292754 6
# 0453456 133607769 4
# 0453456 2112152410 5
# 0453456 2264389978 5
# 0453456 2605988193 28
# 0453456 166683234 6
# 0453456 2136906594 6
# 0453456 2790400354 4
# 0453456 3461475 4
# 0453456 2549033829 4
# 0453456 1978048360 3
# 0453456 2080882283 4
# 0453456 2137489772 5
# 0453456 2095487853 3
# 0453456 111145839 3
# 0453456 2019892337 3
# 0453456 2029349233 3
# 0453456 1975172211 4
# 0453456 2031290229 3
# 0453456 2076550262 4
# 0453456 2577482104 7
# 0453456 2131254650 4
# 0453456 2108708486 4
# 0453456 2782373256 5
# 0453456 2309406858 5
# 0453456 2062368908 3
# 0453456 101800083 4
# 0453456 1985764500 4
# 0453456 1984523156 3
# 0453456 2892503197 7
# 0453456 2103536541 3
# 0453456 2781497761 3
# 0453456 140628899 4
# 0453456 2197804964 9
# 0453456 2040346532 3
# 0453456 2132699814 2
# 0453456 2107735459 3
# 0453456 2135175338 5
# 0453456 2068439723 4
# 0453456 2117590190 4
# 0453456 2631991986 4
# 0453456 1638570163 5
# 0453456 2573243575 5
# 0453456 1970727608 3
# 0453456 2276415419 5
# 0453456 2169980349 6
# 0453456 1978971585 4
# 0453456 2008917955 6
# 0453456 2058008517 4
# 0453456 1990261190 4
# 0453456 2782132425 6
# 0453456 2110709196 6
# 0453456 2167720148 4
# 0453456 2010436308 4
# 0453456 2157767900 4
# 0453456 2778083552 7
# 0453456 2534286564 3
# 0453456 2504273128 4
# 0453456 1964929775 6
# 0453456 1966905333 5
# 0453456 2782044153 4
# 0453456 1968836860 6
# 0453456 2594322175 5
# 0453456 2781554224 4
# 0453456 4695638 5
# 0453456 2773042310 9
# 0453456 1585184399 4
# 0453456 2900166032 5
# 0453456 2185573880 5
# 0453459 814959361 3
# 0453459 2188923019 3
# 0453459 2164929426 2
# 0453459 2100365590 3
# 0453459 2340204833 4
# 0453459 2550981030 3
# 0453459 2152144425 4
# 0453459 2167664560 3
# 0453459 2103323962 14
# 0453459 2119869242 13
# 0453459 2144379199 7
# 0453459 2184471618 4
# 0453459 828291524 13
# 0453459 2120466628 3
# 0453459 2560695120 3
# 0453459 2564005598 9
# 0453459 2566314090 2
# 0453459 2470644214 4
# 0453459 2553086199 3
# 0453459 2100741756 4
# 0453459 2147993981 13
# 0453463 2130578587 7
# 0453463 2088491859 5
# 0453463 2740558685 5
# 0453463 2171072469 3
# 0453463 1791350931 5
# 0453463 2149191060 2
# 0453463 2101566739 2
# 0453463 776434196 5
# 0453463 2274101656 5
# 0453463 1504405274 6
# 0453463 49901725 6
# 0453463 1603796384 5
# 0453463 1976963616 6
# 0453463 2281587747 5
# 0453463 2151355172 6
# 0453463 2146408743 7
# 0453463 2286769833 5
# 0453463 2004271408 5
# 0453463 2271066803 5
# 0453463 1576081715 6
# 0453463 1522889909 3
# 0453463 2733426877 4
# 0453463 2306644299 6
# 0453463 598814028 6
# 0453463 1583870031 5
# 0453463 1483827664 5
# 0453463 2276103635 6
# 0453463 2740558685 5
# 0453463 1694036061 5
# 0453463 64312415 7
# 0453463 2150193893 6
# 0453463 2054348005 6
# 0453463 349355111 5
# 0453463 2412001387 5
# 0453463 2690901743 3
# 0453463 2731041393 3
# 0453463 1575722749 5
# 0453463 1560271998 5
# 0453463 2069840316 5
# 0453463 2740558685 5
# 0454062 2059084416 2
# 0454062 2004503556 3
# 0454062 1546213518 2
# 0454062 2072999566 3
# 0454062 2008399763 3
# 0454062 2147854123 3
# 0454062 1505759662 3
# 0454062 318330546 2
# 0454062 205812916 3
# 0454062 2164489914 4
# 0454062 1975804880 3
# 0454062 2168518742 2
# 0454062 2131434715 11
# 0454062 146708448 2
# 0454062 2097867746 4
# 0454062 2006522216 3
# 0454062 2156368749 3
# 0454062 70097908 3
# 0454062 2126566006 2
# 0454233 2303083265 3
# 0454233 2100228623 7
# 0454233 1596548113 7
# 0454233 2134707735 5
# 0454233 58268960 4
# 0454233 2107671593 3
# 0454233 454144051 6
# 0454233 2171671607 4
# 0454233 178033993 6
# 0454233 2102570318 6
# 0454233 2104598610 3
# 0454233 2115941714 4
# 0454233 2142234711 6
# 0454233 2035161948 5
# 0454233 2019041628 6
# 0454233 2117704033 5
# 0454233 2159668072 6
# 0454233 2114449149 5
# 0454233 2158387825 9
# 0454233 2153581430 7
# 0454233 2154088316 5
# 0454233 2135837828 5
# 0454233 2046604164 6
# 0454233 2130038676 6
# 0454233 2140689817 7
# 0454233 2146474141 3
# 0454233 2127462305 6
# 0454233 2119200170 7
# 0454233 1585406901 6
# 0454233 2478564794 7
# 0454233 2106480581 3
# 0454233 104936390 3
# 0454233 2100866252 6
# 0454233 2131099087 6
# 0454233 1569429725 3
# 0454233 2546309605 4
# 0454233 2134393319 5
# 0454233 2157653492 5
# 0454233 1968600824 7
# 0454233 2263507453 7
# 0454416 2622985504 5
# 0454416 1892753856 2
# 0454416 1544567203 3
# 0454416 2013683463 3
# 0454416 1768571082 5
# 0454416 83039243 3
# 0454416 2105790859 5
# 0454416 94897585 4
# 0454416 2035994874 5
# 0454416 2062001149 4
# 0455998 1984838926 3
# 0455998 1627146914 10
# 0455998 2241663278 10
# 0455998 2008860748 3
# 0455998 2088063089 3
# 0455998 1639389440 5
# 0455998 133937409 5
# 0455998 1642889612 11
# 0455998 1612413583 7
# 0455998 1670288539 9
# 0455998 2064540831 4
# 0455998 1657496483 5
# 0455998 1609129509 6
# 0455998 1651219238 5
# 0455998 1622148734 6
# 0455998 1646444720 6
# 0455998 1614281779 10
# 0455998 1668221630 8
# 0455998 252836030 8
# 0455998 114844998 7
# 0455998 35367119 5
# 0455998 141309779 12
# 0455998 120631766 13
# 0455998 1618585445 6
# 0455998 1655357545 6
# 0455998 1645720173 6
# 0455998 2014010607 5
# 0455998 1671914872 7
# 0455998 1881795838 4
# 86 grants - two PIs collaborated
# Counter({'000': 160, '111': 37, '010': 20, '110': 16, '011': 13})

# %%
for grant_id in two_separate:
    award,_,ts,te,G_all = core.coworknet.get_grant_coworknet_pis(grant_id)
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
#     print(pis)
#     print(grant_id)
    publications = {"pre-grant":0, "grant":0, "post-grant":0}
    citations = {"pre-grant":0, "grant":0, "post-grant":0}
    teams = {"pre-grant":0, "grant":0, "post-grant":0}
    dates = [convert_t(data["date"]) for _,_,data in G.edges.data()]
    for u,v,data in G_all.edges.data():
#         print(data["paper"])
        if u in pis or v in pis:
            coauthor = set()
            for e in G_all.edges.data():
                if e[2]["paper"] == data["paper"]:
                    coauthor.update([e[0], e[1]])
            num_coauthor = len(coauthor)
            if data["grant"] != "other" or (ts <= convert_t(data["date"]) and convert_t(data["date"]) <= te):
                teams["grant"] += num_coauthor
                publications["grant"] += 1
                citations["grant"] += data["citation"]
            elif convert_t(data["date"]) < ts:
                teams["pre-grant"] += num_coauthor
                publications["pre-grant"] += 1
                citations["pre-grant"] += data["citation"]
            elif te < convert_t(data["date"]):
                teams["post-grant"] += num_coauthor
                publications["post-grant"] += 1
                citations["post-grant"] += data["citation"]
    dict_period[grant_id] = (te-ts).days
    dict_amount[grant_id] = award["awardAmount"]
    dict_teams[grant_id] = teams
    dict_publications[grant_id] = publications
    dict_citations[grant_id] = citations
    dict_timestamps[grant_id] = sorted(dates)
#     print(publications, dict_timestamps[grant_id])

for gid in two_separate:
    collab_type[gid] = "two_separate" 
    ctypes.append(collab_type[gid])
    
print(Counter(ctypes))
# Out:
# Counter({'000': 160, '111': 37, '010': 20, '110': 16, 'two_separate': 15, '011': 13})

# %%
for grant_id in only_one_pi:
    award,_,ts,te,G_all = core.coworknet.get_grant_coworknet_pis(grant_id)
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
#     print(pis)
#     print(grant_id)
    publications = {"pre-grant":0, "grant":0, "post-grant":0}
    citations = {"pre-grant":0, "grant":0, "post-grant":0}
    teams = {"pre-grant":0, "grant":0, "post-grant":0}
    dates = [convert_t(data["date"]) for _,_,data in G.edges.data()]
    for u,v,data in G_all.edges.data():
#         print(data["paper"])
        if u in pis or v in pis:
            coauthor = set()
            for e in G_all.edges.data():
                if e[2]["paper"] == data["paper"]:
                    coauthor.update([e[0], e[1]])
            num_coauthor = len(coauthor)
            if data["grant"] != "other" or (ts <= convert_t(data["date"]) and convert_t(data["date"]) <= te):
                teams["grant"] += num_coauthor
                publications["grant"] += 1
                citations["grant"] += data["citation"]
            elif convert_t(data["date"]) < ts:
                teams["pre-grant"] += num_coauthor
                publications["pre-grant"] += 1
                citations["pre-grant"] += data["citation"]
            elif te < convert_t(data["date"]):
                teams["post-grant"] += num_coauthor
                publications["post-grant"] += 1
                citations["post-grant"] += data["citation"]
    dict_period[grant_id] = (te-ts).days
    dict_amount[grant_id] = award["awardAmount"]
    dict_teams[grant_id] = teams
    dict_publications[grant_id] = publications
    dict_citations[grant_id] = citations
    dict_timestamps[grant_id] = sorted(dates)
#     print(publications, dict_timestamps[grant_id])

for gid in only_one_pi:
    collab_type[gid] = "only_one_pi" 
    ctypes.append(collab_type[gid])
    
print(Counter(ctypes))
# Out:
# Counter({'000': 160, 'only_one_pi': 42, '111': 37, '010': 20, '110': 16, 'two_separate': 15, '011': 13})

# %%
set([k for k in dict_timestamps.keys() if collab_type[k] not in ["000", "only_one_pi", "two_separate"]])-set(two_cowork)
# Out:
# {'0429631'}

# %%
x = ["grant"]
ctype = ["010", "011", "110", "111", "only_one_pi", "two_separate"]
box_plot_data = pd.DataFrame({
    "time": [time for time in x for k, v in collab_type.items() if v in ctype],
    "grant_amount": [dict_amount[k] for k, v in collab_type.items() if v in ctype],
    "grant_period": [dict_period[k] for k, v in collab_type.items() if v in ctype],
    "avg_team": [dict_teams[k][time]/dict_publications[k][time] for time in x for k, v in collab_type.items() if v in ctype],
    "publication": [dict_publications[k][time] for time in x for k, v in collab_type.items() if v in ctype],
    "citation": [dict_citations[k][time] for time in x for k, v in collab_type.items() if v in ctype],
    "ctype": [v for time in x for k, v in collab_type.items() if v in ctype]
})
        
# print(box_plot_data.head(5))
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="publication", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Number of publications in grant period")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="citation", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Number of citation of the papers published in grant period")

# %%
box_plot_data["average_citation"] = (box_plot_data["citation"]/box_plot_data["publication"]).fillna(0)
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="average_citation", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Average citations/paper published in grant period")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="grant_period", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Grant period")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="avg_team", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Average number of coauthors per paper")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="grant_amount", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Average grant amount")

# %%
data = {}
years = [2009]
for y in years:
    data.update(core.nsf_utils.load_numpub_data(y))
data = {k:v for k, v in data.items() if v["type"] in grant_type}
for y in years:
    print("[{}]".format(y))
    print("Total number of grants", len([v for v in data.values() if v["year"] == y]))
    for code, desc in div_type.items():
        print(desc, len([v for v in data.values() if v["org"][:4] == code and v["year"] == y]))
# Out:
# [2009]
# Total number of grants 14758
# Division of Computer and Network Systems (CNS) 733
# Division of Computing and Communication Foundations (CCF) 535
# Division of Information and Intelligent Systems (IIS) 627
# Office of Advanced Cyberinfrastructure (OAC) 193

# %%
histogram_num_pis(data, years, div_type.keys())
# Out:
# Counter({1: 1258, 2: 457, 3: 174, 5: 93, 4: 83, 6: 15, 7: 4, 8: 2, 0: 2})

# %%
grant_list = [k for k, d in data.items() if d["org"][:4] in div_type.keys() and d["num_pis"] == 2]
print(len(grant_list), "grants with 2 PIs")
# Out:
# 457 grants with 2 PIs

# %%
no_publications = []
no_edges = []
other = []
only_one_pi = []
two_separate = []
two_cowork = []
for pid in grant_list:
    award, table, ts, te, G_all = core.coworknet.get_grant_coworknet_pis(pid)
    if len(table) == 0:
        no_publications.append(pid)
        continue
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
    G = G_all.subgraph(pis)
        
    working_pis = []
    reported_pub_number = 0
    for k, v in table.items():
        if v["type"]: # only count publicatoins in-grant
            reported_pub_number += 1
            working_pis.append([a for a, av in v["authors"].items() if av["pi"]])
    # print(pid, working_pis)
    pi_counter = [set([n[0]+n.split(" ")[-1] for n in group]) for group in working_pis]
    pi_union = set.union(*pi_counter)
    pi_max_group = max([len(pg) for pg in pi_counter])
#     print(pi_counter, pi_union, pi_max_group)
    print("{} union={}, max_group={}, numpub={} {} {}".format(pid, len(pi_union), pi_max_group, reported_pub_number, len(table), len(G.edges)))
    if len(pi_union) >= 2 and pi_max_group >= 2:
        two_cowork.append(pid)
    elif len(pi_union) >= 2:
        two_separate.append(pid)
    elif len(pi_union) == 1:
        only_one_pi.append(pid)
    else:
        other.append(pid)
print("{} ({:.2f}%) grants have no publication".format(len(no_publications), 100*len(no_publications)/len(grant_list)))
print("{} ({:.2f}%) grants have only one working PI".format(len(only_one_pi), 100*len(only_one_pi)/len(grant_list)))
print("{} ({:.2f}%) grants have two PIs working separately".format(len(two_separate), 100*len(two_separate)/len(grant_list)))
print("{} ({:.2f}%) grants have two PIs collaborated".format(len(two_cowork), 100*len(two_cowork)/len(grant_list)))
print("{} ({:.2f}%) grants are unknown".format(len(other), 100*len(other)/len(grant_list)))
# Out:
# 0902885 union=1, max_group=1, numpub=4 4 0
# 0903191 union=2, max_group=2, numpub=9 28 22
# 0903430 union=2, max_group=2, numpub=8 10 5
# 0903432 union=3, max_group=2, numpub=25 67 44
# 0903437 union=2, max_group=2, numpub=1 96 96
# 0903447 union=2, max_group=2, numpub=2 6 5
# 0903549 union=2, max_group=1, numpub=6 6 0
# 0904116 union=2, max_group=1, numpub=4 4 0
# 0904338 union=1, max_group=1, numpub=14 14 0
# 0904353 union=3, max_group=2, numpub=12 20 9
# 0904431 union=2, max_group=2, numpub=1 17 17
# 0904449 union=2, max_group=2, numpub=6 13 8
# 0904482 union=2, max_group=2, numpub=5 39 39
# 0904501 union=2, max_group=1, numpub=14 14 0
# 0904549 union=1, max_group=1, numpub=1 1 0
# 0904572 union=2, max_group=2, numpub=6 25 21
# 0904597 union=2, max_group=1, numpub=19 19 0
# 0904625 union=2, max_group=2, numpub=10 17 12
# 0904631 union=2, max_group=1, numpub=47 47 0
# 0904672 union=1, max_group=1, numpub=3 3 0
# 0904684 union=1, max_group=1, numpub=2 2 0
# 0904729 union=2, max_group=2, numpub=7 17 15
# 0904754 union=1, max_group=1, numpub=1 1 0
# 0904782 union=2, max_group=2, numpub=53 53 8
# 0904879 union=2, max_group=2, numpub=5 50 50
# 0904952 union=1, max_group=1, numpub=2 2 0
# 0905008 union=2, max_group=2, numpub=18 31 17
# 0905014 union=3, max_group=2, numpub=17 57 47
# 0905032 union=2, max_group=2, numpub=1 15 15
# 0905059 union=1, max_group=1, numpub=3 3 0
# 0905127 union=2, max_group=2, numpub=2 11 11
# 0905134 union=0, max_group=0, numpub=1 1 0
# 0905164 union=2, max_group=2, numpub=6 39 38
# 0905215 union=2, max_group=2, numpub=44 91 50
# 0905220 union=2, max_group=2, numpub=18 19 3
# 0905228 union=1, max_group=1, numpub=2 2 0
# 0905237 union=2, max_group=2, numpub=4 24 21
# 0905244 union=1, max_group=1, numpub=1 1 0
# 0905250 union=2, max_group=2, numpub=7 8 3
# 0905276 union=2, max_group=2, numpub=13 35 26
# 0905291 union=1, max_group=1, numpub=8 8 0
# 0905331 union=2, max_group=2, numpub=17 22 10
# 0905337 union=1, max_group=1, numpub=14 14 0
# 0905349 union=2, max_group=1, numpub=4 4 0
# 0905365 union=1, max_group=1, numpub=9 9 0
# 0905370 union=2, max_group=2, numpub=3 5 3
# 0905385 union=2, max_group=2, numpub=10 76 71
# 0905447 union=2, max_group=2, numpub=10 28 21
# 0905464 union=2, max_group=2, numpub=3 20 18
# 0905467 union=2, max_group=2, numpub=13 15 3
# 0905478 union=1, max_group=1, numpub=2 2 0
# 0905530 union=1, max_group=1, numpub=1 1 0
# 0905541 union=2, max_group=2, numpub=5 14 10
# 0905562 union=1, max_group=1, numpub=3 3 0
# 0905565 union=2, max_group=1, numpub=2 2 0
# 0905584 union=1, max_group=1, numpub=8 8 0
# 0905596 union=1, max_group=1, numpub=8 8 0
# 0905602 union=2, max_group=2, numpub=10 15 6
# 0905603 union=2, max_group=1, numpub=4 4 0
# 0905622 union=2, max_group=2, numpub=2 41 40
# 0905625 union=2, max_group=2, numpub=2 39 38
# 0910485 union=2, max_group=2, numpub=2 10 9
# 0910702 union=2, max_group=2, numpub=11 21 11
# 0910706 union=2, max_group=1, numpub=4 4 0
# 0910820 union=2, max_group=2, numpub=2 2 1
# 0910838 union=2, max_group=2, numpub=7 218 217
# 0910878 union=1, max_group=1, numpub=5 5 0
# 0910899 union=1, max_group=1, numpub=3 3 0
# 0910989 union=2, max_group=2, numpub=7 22 17
# 0910992 union=1, max_group=1, numpub=5 5 0
# 0913875 union=2, max_group=1, numpub=13 13 0
# 0914312 union=1, max_group=1, numpub=3 3 0
# 0914371 union=2, max_group=2, numpub=27 30 6
# 0914615 union=2, max_group=2, numpub=3 31 31
# 0914808 union=1, max_group=1, numpub=11 11 0
# 0914845 union=1, max_group=1, numpub=1 1 0
# 0914877 union=2, max_group=2, numpub=3 10 8
# 0915016 union=2, max_group=2, numpub=8 21 14
# 0915071 union=2, max_group=2, numpub=2 12 12
# 0915145 union=2, max_group=2, numpub=21 25 7
# 0915270 union=2, max_group=2, numpub=3 3 1
# 0915302 union=2, max_group=2, numpub=1 5 5
# 0915462 union=2, max_group=2, numpub=15 20 9
# 0915543 union=2, max_group=2, numpub=10 17 8
# 0915552 union=2, max_group=2, numpub=2 47 46
# 0915559 union=1, max_group=1, numpub=3 3 0
# 0915665 union=1, max_group=1, numpub=1 1 0
# 0915697 union=1, max_group=1, numpub=1 1 0
# 0915727 union=2, max_group=2, numpub=13 86 84
# 0915762 union=1, max_group=1, numpub=9 9 0
# 0915782 union=1, max_group=1, numpub=4 4 0
# 0915800 union=2, max_group=1, numpub=9 9 0
# 0915803 union=2, max_group=2, numpub=2 21 21
# 0915805 union=1, max_group=1, numpub=1 1 0
# 0915813 union=2, max_group=2, numpub=2 3 2
# 0915851 union=1, max_group=1, numpub=2 2 0
# 0915862 union=2, max_group=2, numpub=7 8 7
# 0915899 union=2, max_group=2, numpub=5 6 2
# 0915912 union=2, max_group=2, numpub=4 12 11
# 0915926 union=2, max_group=2, numpub=3 25 23
# 0915945 union=2, max_group=2, numpub=7 21 15
# 0915976 union=1, max_group=1, numpub=3 3 0
# 0915985 union=2, max_group=1, numpub=7 7 0
# 0915996 union=0, max_group=0, numpub=1 1 0
# 0916014 union=2, max_group=2, numpub=1 20 20
# 0916035 union=1, max_group=1, numpub=2 2 0
# 0916044 union=2, max_group=2, numpub=4 31 31
# 0916047 union=2, max_group=2, numpub=11 12 2
# 0916081 union=2, max_group=2, numpub=2 7 6
# 0916083 union=2, max_group=2, numpub=6 11 6
# 0916102 union=2, max_group=2, numpub=8 15 11
# 0916105 union=1, max_group=1, numpub=6 6 0
# 0916106 union=2, max_group=2, numpub=4 44 42
# 0916112 union=1, max_group=1, numpub=1 1 0
# 0916152 union=1, max_group=1, numpub=1 1 0
# 0916171 union=2, max_group=1, numpub=15 15 0
# 0916180 union=2, max_group=2, numpub=9 57 53
# 0916196 union=1, max_group=1, numpub=3 3 0
# 0916200 union=1, max_group=1, numpub=3 3 0
# 0916217 union=2, max_group=2, numpub=1 3 3
# 0916219 union=2, max_group=1, numpub=3 3 0
# 0916221 union=2, max_group=2, numpub=5 14 10
# 0916235 union=4, max_group=2, numpub=17 23 10
# 0916286 union=3, max_group=2, numpub=11 13 3
# 0916289 union=2, max_group=2, numpub=18 36 27
# 0916307 union=1, max_group=1, numpub=2 2 0
# 0916323 union=2, max_group=2, numpub=1 18 18
# 0916389 union=2, max_group=2, numpub=6 31 27
# 0916415 union=1, max_group=1, numpub=1 1 0
# 0916425 union=2, max_group=2, numpub=7 40 35
# 0916436 union=2, max_group=1, numpub=8 8 0
# 0916439 union=2, max_group=2, numpub=17 107 102
# 0916452 union=2, max_group=1, numpub=12 12 0
# 0916515 union=2, max_group=2, numpub=7 24 19
# 0916534 union=1, max_group=1, numpub=5 5 0
# 0916555 union=1, max_group=1, numpub=3 3 0
# 0916557 union=2, max_group=2, numpub=4 21 18
# 0916568 union=2, max_group=2, numpub=3 17 17
# 0916574 union=2, max_group=2, numpub=6 39 35
# 0916577 union=2, max_group=1, numpub=11 11 0
# 0916583 union=1, max_group=1, numpub=3 3 0
# 0916584 union=2, max_group=2, numpub=6 11 8
# 0916624 union=2, max_group=2, numpub=7 27 21
# 0916664 union=2, max_group=1, numpub=39 39 0
# 0916687 union=2, max_group=2, numpub=3 11 9
# 0916691 union=1, max_group=1, numpub=1 1 0
# 0916708 union=2, max_group=2, numpub=9 50 43
# 0916716 union=2, max_group=2, numpub=4 6 6
# 0916720 union=2, max_group=1, numpub=24 24 0
# 0916725 union=2, max_group=2, numpub=8 91 86
# 0916734 union=2, max_group=2, numpub=6 27 23
# 0916736 union=2, max_group=2, numpub=12 20 12
# 0916746 union=2, max_group=2, numpub=4 15 12
# 0916750 union=2, max_group=2, numpub=16 17 2
# 0916763 union=2, max_group=2, numpub=1 8 8
# 0916817 union=2, max_group=1, numpub=4 4 0
# 0916829 union=2, max_group=2, numpub=11 14 5
# 0916852 union=2, max_group=2, numpub=9 16 13
# 0916854 union=2, max_group=2, numpub=4 11 10
# 0916878 union=2, max_group=2, numpub=1 31 31
# 0916887 union=2, max_group=2, numpub=1 36 36
# 0916891 union=2, max_group=2, numpub=9 9 1
# 0916892 union=2, max_group=2, numpub=6 35 32
# 0916893 union=2, max_group=2, numpub=17 20 5
# 0916918 union=1, max_group=1, numpub=3 3 0
# 0916947 union=1, max_group=1, numpub=11 11 0
# 0916948 union=2, max_group=1, numpub=15 15 0
# 0916958 union=2, max_group=1, numpub=3 3 0
# 0917000 union=2, max_group=2, numpub=5 17 14
# 0917008 union=2, max_group=2, numpub=7 57 53
# 0917012 union=1, max_group=1, numpub=2 2 0
# 0917057 union=2, max_group=1, numpub=5 5 0
# 0917070 union=2, max_group=2, numpub=13 23 12
# 0917078 union=1, max_group=1, numpub=1 1 0
# 0917096 union=2, max_group=2, numpub=2 6 5
# 0917167 union=1, max_group=1, numpub=8 8 0
# 0917175 union=2, max_group=2, numpub=6 75 72
# 0917194 union=1, max_group=1, numpub=2 2 0
# 0917204 union=2, max_group=2, numpub=3 10 10
# 0917213 union=2, max_group=2, numpub=1 7 7
# 0917218 union=1, max_group=1, numpub=1 1 0
# 0917226 union=1, max_group=1, numpub=4 4 0
# 0917229 union=1, max_group=1, numpub=2 2 0
# 0917230 union=2, max_group=1, numpub=8 8 0
# 0917232 union=2, max_group=2, numpub=1 6 6
# 0917233 union=3, max_group=2, numpub=7 12 7
# 0917238 union=1, max_group=1, numpub=5 5 0
# 0917251 union=2, max_group=2, numpub=6 22 18
# 0917257 union=1, max_group=1, numpub=4 4 0
# 0917261 union=2, max_group=2, numpub=3 66 64
# 0917265 union=2, max_group=2, numpub=7 32 29
# 0917274 union=2, max_group=2, numpub=29 74 67
# 0917288 union=2, max_group=2, numpub=20 50 33
# 0917315 union=2, max_group=2, numpub=1 9 9
# 0917340 union=2, max_group=2, numpub=1 1 1
# 0917341 union=1, max_group=1, numpub=4 4 0
# 0917342 union=2, max_group=1, numpub=7 7 0
# 0917343 union=2, max_group=1, numpub=8 8 0
# 0917362 union=1, max_group=1, numpub=2 2 0
# 0917379 union=1, max_group=1, numpub=1 1 0
# 0917398 union=1, max_group=1, numpub=11 11 0
# 0917401 union=2, max_group=2, numpub=7 9 3
# 0917408 union=1, max_group=1, numpub=1 1 0
# 0917816 union=2, max_group=2, numpub=3 15 15
# 0922996 union=1, max_group=1, numpub=9 9 0
# 0923152 union=2, max_group=2, numpub=2 5 4
# 0923386 union=1, max_group=1, numpub=13 13 0
# 0924385 union=1, max_group=1, numpub=3 3 0
# 0926701 union=1, max_group=1, numpub=8 8 0
# 0930081 union=1, max_group=1, numpub=5 5 0
# 0930477 union=2, max_group=2, numpub=1 1 1
# 0930647 union=2, max_group=2, numpub=4 193 193
# 0930746 union=2, max_group=2, numpub=21 49 35
# 0930813 union=2, max_group=1, numpub=4 4 0
# 0931035 union=2, max_group=2, numpub=6 40 37
# 0931195 union=2, max_group=1, numpub=3 3 0
# 0931416 union=2, max_group=2, numpub=18 45 32
# 0931474 union=2, max_group=2, numpub=18 20 6
# 0931576 union=1, max_group=1, numpub=4 4 0
# 0931693 union=2, max_group=2, numpub=12 44 35
# 0931871 union=1, max_group=1, numpub=9 9 0
# 0931885 union=1, max_group=1, numpub=13 13 0
# 0931969 union=4, max_group=2, numpub=21 46 37
# 0931985 union=1, max_group=1, numpub=3 3 0
# 0931992 union=2, max_group=1, numpub=6 6 0
# 0931999 union=2, max_group=2, numpub=3 12 11
# 0932069 union=1, max_group=1, numpub=1 1 0
# 0932389 union=2, max_group=2, numpub=2 2 1
# 0932397 union=2, max_group=2, numpub=2 23 22
# 0932423 union=1, max_group=1, numpub=1 1 0
# 0934364 union=2, max_group=2, numpub=4 21 19
# 0937690 union=1, max_group=1, numpub=3 3 0
# 0937810 union=1, max_group=1, numpub=2 2 0
# 0937833 union=2, max_group=2, numpub=26 26 1
# 0937854 union=2, max_group=2, numpub=11 18 9
# 0937860 union=2, max_group=2, numpub=34 54 21
# 0937908 union=2, max_group=2, numpub=7 12 7
# 0937925 union=2, max_group=2, numpub=21 60 46
# 0937938 union=0, max_group=0, numpub=1 1 0
# 0937959 union=2, max_group=2, numpub=4 151 151
# 0937993 union=1, max_group=1, numpub=3 3 0
# 0938000 union=2, max_group=2, numpub=7 128 127
# 0939002 union=2, max_group=2, numpub=4 6 3
# 0939081 union=2, max_group=2, numpub=1 6 6
# 0939097 union=2, max_group=2, numpub=1 5 5
# 0939187 union=2, max_group=2, numpub=8 72 67
# 0941078 union=1, max_group=1, numpub=3 3 0
# 0941085 union=2, max_group=2, numpub=1 137 137
# 0941581 union=2, max_group=2, numpub=2 125 125
# 0941735 union=2, max_group=2, numpub=4 13 13
# 0943069 union=1, max_group=1, numpub=1 1 0
# 0943148 union=2, max_group=2, numpub=9 12 6
# 0943168 union=2, max_group=2, numpub=12 16 6
# 0943184 union=1, max_group=1, numpub=1 1 0
# 0943203 union=2, max_group=2, numpub=1 5 5
# 0943385 union=2, max_group=1, numpub=10 10 0
# 0943505 union=0, max_group=0, numpub=3 3 0
# 0944125 union=2, max_group=2, numpub=6 23 21
# 0944131 union=1, max_group=1, numpub=1 1 0
# 0946273 union=2, max_group=2, numpub=2 80 80
# 0946400 union=2, max_group=1, numpub=14 14 0
# 0946601 union=2, max_group=2, numpub=6 22 22
# 0947679 union=2, max_group=2, numpub=5 5 3
# 0948424 union=2, max_group=2, numpub=1 14 14
# 0948601 union=2, max_group=1, numpub=6 6 0
# 0948893 union=2, max_group=2, numpub=2 12 12
# 0948901 union=0, max_group=0, numpub=1 1 0
# 0949667 union=2, max_group=2, numpub=2 2 1
# 0950440 union=2, max_group=2, numpub=6 14 11
# 0952287 union=1, max_group=1, numpub=1 1 0
# 0953749 union=1, max_group=1, numpub=13 13 0
# 0953994 union=2, max_group=2, numpub=2 13 13
# 0954310 union=1, max_group=1, numpub=1 1 0
# 0956311 union=2, max_group=2, numpub=2 4 4
# 0956501 union=2, max_group=2, numpub=10 28 19
# 0957394 union=2, max_group=2, numpub=4 22 19
# 0957718 union=2, max_group=2, numpub=4 4 1
# 0958123 union=1, max_group=1, numpub=1 1 0
# 0958193 union=1, max_group=1, numpub=1 1 0
# 0958303 union=2, max_group=2, numpub=1 6 6
# 0958345 union=1, max_group=1, numpub=6 6 1
# 0958436 union=2, max_group=2, numpub=2 25 25
# 0958442 union=2, max_group=2, numpub=1 7 7
# 0958487 union=2, max_group=1, numpub=5 5 0
# 0958490 union=2, max_group=2, numpub=1 3 3
# 0958585 union=2, max_group=2, numpub=7 12 6
# 0959096 union=2, max_group=2, numpub=8 32 27
# 0961234 union=1, max_group=1, numpub=4 4 0
# 0963081 union=2, max_group=2, numpub=1 1 1
# 0963204 union=1, max_group=1, numpub=1 1 0
# 0963478 union=1, max_group=1, numpub=2 2 0
# 0963695 union=2, max_group=2, numpub=2 5 4
# 0963702 union=1, max_group=1, numpub=3 3 0
# 0963717 union=1, max_group=1, numpub=5 5 0
# 0963742 union=2, max_group=2, numpub=13 14 3
# 0963754 union=2, max_group=2, numpub=6 71 67
# 0963757 union=2, max_group=2, numpub=6 17 17
# 0963759 union=3, max_group=1, numpub=10 10 0
# 0963834 union=2, max_group=2, numpub=7 8 2
# 0963922 union=2, max_group=1, numpub=4 4 0
# 0963925 union=2, max_group=2, numpub=20 24 5
# 0963993 union=1, max_group=1, numpub=14 14 0
# 0963996 union=1, max_group=1, numpub=2 2 0
# 0964004 union=1, max_group=1, numpub=3 3 0
# 0964037 union=1, max_group=1, numpub=18 18 0
# 0964075 union=2, max_group=2, numpub=4 126 125
# 0964079 union=0, max_group=0, numpub=3 3 0
# 0964081 union=2, max_group=1, numpub=6 6 0
# 0964215 union=2, max_group=1, numpub=7 7 0
# 0964218 union=2, max_group=2, numpub=2 19 18
# 0964236 union=1, max_group=1, numpub=9 9 0
# 0964269 union=1, max_group=1, numpub=1 1 0
# 0964294 union=2, max_group=1, numpub=4 4 0
# 0964302 union=2, max_group=2, numpub=13 26 15
# 0964324 union=2, max_group=2, numpub=5 9 6
# 0964334 union=2, max_group=2, numpub=2 24 23
# 0964357 union=2, max_group=2, numpub=6 10 5
# 0964409 union=2, max_group=1, numpub=7 7 0
# 0964412 union=1, max_group=1, numpub=19 19 0
# 0964413 union=2, max_group=2, numpub=5 26 23
# 0964471 union=2, max_group=2, numpub=5 18 14
# 0964474 union=1, max_group=1, numpub=2 2 0
# 0964479 union=1, max_group=1, numpub=3 3 0
# 0964545 union=2, max_group=2, numpub=5 9 7
# 0964560 union=2, max_group=2, numpub=10 20 11
# 0964581 union=1, max_group=1, numpub=6 6 0
# 0964590 union=2, max_group=2, numpub=3 36 34
# 0964592 union=1, max_group=1, numpub=2 2 0
# 0964606 union=2, max_group=2, numpub=7 11 5
# 0964627 union=2, max_group=1, numpub=11 11 0
# 0964634 union=2, max_group=2, numpub=10 21 12
# 0964652 union=2, max_group=2, numpub=7 26 24
# 0964681 union=2, max_group=2, numpub=6 9 4
# 0964695 union=2, max_group=1, numpub=4 4 0
# 0964696 union=2, max_group=2, numpub=12 17 8
# 0964705 union=2, max_group=2, numpub=3 51 49
# 0968483 union=1, max_group=1, numpub=4 4 0
# 0968485 union=0, max_group=0, numpub=1 1 0
# 0968561 union=2, max_group=2, numpub=7 7 1
# 0968588 union=1, max_group=1, numpub=3 3 0
# 0968959 union=0, max_group=0, numpub=13 13 0
# 0970179 union=0, max_group=0, numpub=3 3 0
# 115 (25.16%) grants have no publication
# 102 (22.32%) grants have only one working PI
# 41 (8.97%) grants have two PIs working separately
# 190 (41.58%) grants have two PIs collaborated
# 9 (1.97%) grants are unknown

# %%
collab_type = {}
dict_period = {}
dict_amount = {}
dict_teams = {}
dict_publications = {}
dict_citations = {}
dict_timestamps = {}
convert_t = lambda t: datetime.strptime(t, "%Y-%m-%dT%X")

for grant_id in grant_list:
    award,_,ts,te,G_all = core.coworknet.get_grant_coworknet_pis(grant_id)
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
#     print(pis)
    G = G_all.subgraph(pis)
#     if len(G.edges) == 0:
#         continue
        
#     print(grant_id)
    publications = {"pre-grant":0, "grant":0, "post-grant":0}
    citations = {"pre-grant":0, "grant":0, "post-grant":0}
    teams = {"pre-grant":0, "grant":0, "post-grant":0}
    dates = [convert_t(data["date"]) for _,_,data in G.edges.data()]
    for u,v,data in G.edges.data():
#         print(data["paper"])
        coauthor = set()
        for e in G_all.edges.data():
            if e[2]["paper"] == data["paper"]:
                coauthor.update([e[0], e[1]])
        num_coauthor = len(coauthor)
#         print(data["paper"], num_coauthor)
        if data["grant"] != "other" or (ts <= convert_t(data["date"]) and convert_t(data["date"]) <= te):
#             print("grant") # reported publications or unreported pubs in the grant period
            teams["grant"] += num_coauthor
            publications["grant"] += 1
            citations["grant"] += data["citation"]
        elif convert_t(data["date"]) < ts:
#             print("pre-grant") # unreported publications before the grant period
            teams["pre-grant"] += num_coauthor
            publications["pre-grant"] += 1
            citations["pre-grant"] += data["citation"]
        elif te < convert_t(data["date"]):
#             print("post-grant") # unreported publications after the grant period
            teams["post-grant"] += num_coauthor
            publications["post-grant"] += 1
            citations["post-grant"] += data["citation"]
    dict_period[grant_id] = (te-ts).days
    dict_amount[grant_id] = award["awardAmount"]
    dict_teams[grant_id] = teams
    dict_publications[grant_id] = publications
    dict_citations[grant_id] = citations
    dict_timestamps[grant_id] = sorted(dates)
#     print(publications, dict_timestamps[grant_id])

ctypes = []
for gid, v in dict_publications.items():
    collab_type[gid] = "{}{}{}".format(1 if v["pre-grant"]>0 else 0, 1 if v["grant"]>0 else 0, 1 if v["post-grant"]>0 else 0)
    ctypes.append(collab_type[gid])
    
print(len([k for k in dict_timestamps.keys() if collab_type[k] != "000"]), "grants - two PIs collaborated")
print(Counter(ctypes))
# Out:
# 191 grants - two PIs collaborated
# Counter({'000': 266, '111': 97, '011': 37, '010': 30, '110': 27})

# %%
for grant_id in two_separate:
    award,_,ts,te,G_all = core.coworknet.get_grant_coworknet_pis(grant_id)
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
#     print(pis)
#     print(grant_id)
    publications = {"pre-grant":0, "grant":0, "post-grant":0}
    citations = {"pre-grant":0, "grant":0, "post-grant":0}
    teams = {"pre-grant":0, "grant":0, "post-grant":0}
    dates = [convert_t(data["date"]) for _,_,data in G.edges.data()]
    for u,v,data in G_all.edges.data():
#         print(data["paper"])
        if u in pis or v in pis:
            coauthor = set()
            for e in G_all.edges.data():
                if e[2]["paper"] == data["paper"]:
                    coauthor.update([e[0], e[1]])
            num_coauthor = len(coauthor)
            if data["grant"] != "other" or (ts <= convert_t(data["date"]) and convert_t(data["date"]) <= te):
                teams["grant"] += num_coauthor
                publications["grant"] += 1
                citations["grant"] += data["citation"]
            elif convert_t(data["date"]) < ts:
                teams["pre-grant"] += num_coauthor
                publications["pre-grant"] += 1
                citations["pre-grant"] += data["citation"]
            elif te < convert_t(data["date"]):
                teams["post-grant"] += num_coauthor
                publications["post-grant"] += 1
                citations["post-grant"] += data["citation"]
    dict_period[grant_id] = (te-ts).days
    dict_amount[grant_id] = award["awardAmount"]
    dict_teams[grant_id] = teams
    dict_publications[grant_id] = publications
    dict_citations[grant_id] = citations
    dict_timestamps[grant_id] = sorted(dates)
#     print(publications, dict_timestamps[grant_id])

for gid in two_separate:
    collab_type[gid] = "two_separate" 
    ctypes.append(collab_type[gid])
    
print(Counter(ctypes))
# Out:
# Counter({'000': 266, '111': 97, 'two_separate': 41, '011': 37, '010': 30, '110': 27})

# %%
for grant_id in only_one_pi:
    award,_,ts,te,G_all = core.coworknet.get_grant_coworknet_pis(grant_id)
    pis = [a for a in G_all.nodes() if "pi" in G_all.nodes[a] and G_all.nodes[a] ["pi"]]
#     print(pis)
#     print(grant_id)
    publications = {"pre-grant":0, "grant":0, "post-grant":0}
    citations = {"pre-grant":0, "grant":0, "post-grant":0}
    teams = {"pre-grant":0, "grant":0, "post-grant":0}
    dates = [convert_t(data["date"]) for _,_,data in G.edges.data()]
    for u,v,data in G_all.edges.data():
#         print(data["paper"])
        if u in pis or v in pis:
            coauthor = set()
            for e in G_all.edges.data():
                if e[2]["paper"] == data["paper"]:
                    coauthor.update([e[0], e[1]])
            num_coauthor = len(coauthor)
            if data["grant"] != "other" or (ts <= convert_t(data["date"]) and convert_t(data["date"]) <= te):
                teams["grant"] += num_coauthor
                publications["grant"] += 1
                citations["grant"] += data["citation"]
            elif convert_t(data["date"]) < ts:
                teams["pre-grant"] += num_coauthor
                publications["pre-grant"] += 1
                citations["pre-grant"] += data["citation"]
            elif te < convert_t(data["date"]):
                teams["post-grant"] += num_coauthor
                publications["post-grant"] += 1
                citations["post-grant"] += data["citation"]
    dict_period[grant_id] = (te-ts).days
    dict_amount[grant_id] = award["awardAmount"]
    dict_teams[grant_id] = teams
    dict_publications[grant_id] = publications
    dict_citations[grant_id] = citations
    dict_timestamps[grant_id] = sorted(dates)
#     print(publications, dict_timestamps[grant_id])

for gid in only_one_pi:
    collab_type[gid] = "only_one_pi" 
    ctypes.append(collab_type[gid])
    
print(Counter(ctypes))
# Out:
# Counter({'000': 266, 'only_one_pi': 102, '111': 97, 'two_separate': 41, '011': 37, '010': 30, '110': 27})

# %%
set([k for k in dict_timestamps.keys() if collab_type[k] not in ["000", "only_one_pi", "two_separate"]])-set(two_cowork)
# Out:
# set()

# %%
x = ["grant"]
ctype = ["010", "011", "110", "111", "only_one_pi", "two_separate"]
box_plot_data = pd.DataFrame({
    "time": [time for time in x for k, v in collab_type.items() if v in ctype],
    "grant_amount": [dict_amount[k] for k, v in collab_type.items() if v in ctype],
    "grant_period": [dict_period[k] for k, v in collab_type.items() if v in ctype],
    "avg_team": [dict_teams[k][time]/dict_publications[k][time] if dict_publications[k][time] > 0 else 0 for time in x for k, v in collab_type.items() if v in ctype],
    "publication": [dict_publications[k][time] for time in x for k, v in collab_type.items() if v in ctype],
    "citation": [dict_citations[k][time] for time in x for k, v in collab_type.items() if v in ctype],
    "ctype": [v for time in x for k, v in collab_type.items() if v in ctype]
})
        
# print(box_plot_data.head(5))
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="publication", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Number of publications in grant period")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="citation", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Number of citation of the papers published in grant period")

# %%
box_plot_data["average_citation"] = (box_plot_data["citation"]/box_plot_data["publication"]).fillna(0)
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="average_citation", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Average citations/paper published in grant period")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="grant_period", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Grant period")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="avg_team", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Average number of coauthors per paper")

# %%
plt.figure(figsize=(6,8))
ax = sns.boxplot(x="time", y="grant_amount", hue="ctype", data=box_plot_data, showmeans=True, hue_order=ctype).set_title("Average grant amount")
