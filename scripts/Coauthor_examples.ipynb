# %%
import os,sys,json
import core.nsf_utils, core.openaire_utils

import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

# %%
# Manually normalized PI names
# data = [
#     {"id": 1017296, "PIs": ["H. V. Jagadish"]},
#     {"id": 540866, "PIs": ["Antony L. Hosking"]},
#     {"id": 811691, "PIs": ["Jan Vitek", "Antony L. Hosking"]},
#     {"id": 934218, "PIs": ["Dhiraj K. Sardar", "Igal Szleifer", "Fidel Santamaria", "Xomalin G. Peralta"]},
#     {"id": 926127, "PIs": ["Jason Cong", "Jens Palsberg", "Glenn Reinman", "Vivek Sarkar", "Alex A. T. Bui"]},
#     {"id": 1027253, "PIs": ["G. Philip Robertson", "Douglas A. Landis", "Thomas M. Schmidt", "Katherine L. Gross", "Stephen K. Hamilton"]},
#     {"id": 922742, "PIs": ["Claude W. dePamphilis", "Pamela S. Soltis", "Jim Leebens-Mack", "W. Brad Barbazuk", "Victor A. Albert"]}
# ]

# %%
def plot_coauthor_net(award_id, title_printout=True):
    dup_titles, total_titles, G, pis = core.nsf_utils.publication_analysis(award_id, title_printout=title_printout)
    print("\n* {}/{} duplicated papers are removed.".format(dup_titles, dup_titles+total_titles))
    print("* {} PIs, {}".format(len(pis), pis))
    pos = nx.spring_layout(G)
    new_PI_list = []
    for pi in pis:
        if pi not in G.nodes:
            print("Node '{}' has no position.".format(pi))
        else:
            new_PI_list.append(pi)
    nx.draw(G, pos)
    try:
        nx.draw_networkx_nodes(G, pos, nodelist=new_PI_list, node_color='r')
    except Exception as e:
        print(e)
    plt.show()

# %%
plot_coauthor_net("1017296")
# Out:
# ['H. V. Jagadish', 'Guoliang Li', 'He Wen', 'Dong Deng', 'Jianhua Feng'] meta an efficient matching based method for error tolerant autocompletion
# ['H. V. Jagadish', 'Li Qian', 'Kristen LeFevre'] crius user friendly database design
# ['Chen Caleb Cao', 'Chen Jason Zhang', 'Lei Chen', 'H. V. Jagadish'] reducing uncertainty of schema matching via crowdsourcing
# ['Fei Li', 'H. V. Jagadish'] constructing an interactive natural language interface for relational databases
# ['Li Qian', 'Michael J. Cafarella', 'H. V. Jagadish'] sample driven schema mapping
# ['H. V. Jagadish', 'Jinyang Gao', 'Li Qian'] learning user preferences by adaptive pairwise comparison
# ['Zhifeng Bao', 'Dongxiang Zhang', 'Tok Wang Ling', 'H. V. Jagadish', 'Yong Zeng', 'Guoliang Li'] a general framework to resolve the mismatch problem in xml keyword search
# ['H. V. Jagadish', 'Li Qian', 'Arnab Nandi'] organic databases
# ['Fei Li', 'H. V. Jagadish'] usability databases and hci
# ['Hao Zhou', 'George Michailidis', 'H. V. Jagadish', 'Anna A. Shaverdian'] a graph algebra for scalable visual analytics
# ['H. V. Jagadish', 'Arnab Nandi', 'Manish Singh'] skimmer rapid scrolling of relational query results
# ['H. V. Jagadish', 'Arnab Nandi'] guided interaction rethinking the query result paradigm
#
# * 6/24 duplicated papers are removed.
# * 1 PIs, ['H. V. Jagadish']
# /Users/minjeongshin/miniconda2/envs/mm/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
plot_coauthor_net("0540866")
# Out:
# ['Maria Jump', 'Stephen M. Blackburn', 'Thomas VanDrunen', 'Antony L. Hosking', 'J. Eliot B. Moss', 'Aashish Phansalkar', 'Darko Stefanovik', 'Ben Wiedermann', 'Amer Diwan', 'Kathryn S. McKinley'] wake up and smell the coffee evaluation methodology for the 21st century
# ['Tatiana Shpeisman', 'J. Eliot B. Moss', 'Vijay Menon', 'Bratin Saha', 'Antony L. Hosking', 'Richard L. Hudson', 'Ali-Reza Adl-Tabatabai', 'Yang Ni'] open nesting in software transactional memory
# ['Antony L. Hosking'] portable mostly concurrent mostly copying garbage collection for multi processors
# ['Antony L. Hosking', 'Phil McGachey'] reducing generational copy reserve overhead with fallback compaction
# ['Ben Wiedermann', 'Amer Diwan', 'Robin Garner', 'Kathryn S. McKinley', 'Chris Hoffmann', 'Martin Hirzel', 'Samuel Z. Guyer', 'Daniel Frampton', 'Thomas VanDrunen', 'Maria Jump'] the dacapo benchmarks java benchmarking development and analysis
# ['Antony L. Hosking', 'Adam Welc', 'Suresh Jagannathan'] revocation techniques for java concurrency
# ['Antony L. Hosking', 'Adam Welc', 'Suresh Jagannathan'] transparently reconciling transactions with locking for java synchronization
# ['Filip Pizlo', 'Anthony L. Hosking', 'Jan Vitek'] hierarchical real time garbage collection
# ['Richard L. Hudson', 'Ali-Reza Adl-Tabatabai', 'Bratin Saha', 'Vijay Menon', 'Tatiana Shpeisman', 'Phil McGachey'] concurrent gc leveraging transactional memory
# ['J. Eliot B. Moss', 'Antony L. Hosking'] nested transactional memory model and architecture sketches
#
# * 0/10 duplicated papers are removed.
# * 1 PIs, ['Antony L. Hosking']

# %%
plot_coauthor_net("0811691")
# Out:
# ['Laurence Hellyer', 'Antony L. Hosking', 'Richard Jones'] the locality of concurrent write barriers
# ['Jan Vitek', 'Ghaith Haddad', 'Gary T. Leavens', 'Tomas Kalibera', 'Pavel Parizek'] challenge benchmarks for verification of real time programs
# ['Vitek Jan', 'Kalibera Tomas', 'Filip Pizlo', 'Ales Plsek', 'Ben L. Titzer', 'Hagelberg Jeff'] cdx a family of real time java benchmarks tomas
# ['Filip Pizlo', 'Jan Vitek', 'Tomas Kalibera', 'Antonio Cunei', 'Jason Baker'] accurate garbage collection in uncooperative environments revisited
# ['Daniel Frampton', 'Filip Pizlo', 'Antony L. Hosking'] fine grained adaptive biased locking
# ['Jan Vitek'] programming models for concurrency and real time
# ['Daniel Tang', 'Lei Zhao', 'Jan Vitek'] a technology compatibility kit for safety critical java
# ['Petr Maj', 'Jan Vitek', 'Antony L. Hosking', 'Filip Pizlo', 'Lukasz Ziarek', 'Ethan Blanton'] schism fragmentation tolerant real time garbage collection
# ['Antony L. Hosking', 'Stephen M. Blackburn', 'Daniel Frampton', 'Xi Yang'] barriers reconsidered friendlier still
# ['Filip Pizlo', 'Lukasz Ziarek', 'Jan Vitek'] real time java on resource constrained platforms with fiji vm
# ['Martin Schoeberl', 'Florian Brandner', 'Jan Vitek'] rttm real time transactional memory
# ['Antony L. Hosking', 'Tomas Kalibera', 'Jan Vitek', 'Filip Pizlo'] scheduling real time garbage collection on uniprocessors
# ['Jean Privat', 'Rachid Guerraoui', 'Filip Pizlo', 'Jan Vitek', 'Jesper Honig Spring'] reflexes abstractions for integrating highly responsive tasks into java applications
# ['Jan Vitek', 'Tomas Kalibera', 'Marek Prochazka', 'Martin Decky', 'Marco Zulianello', 'Filip Pizlo'] real time java in space potential benefits and open challenges
# ['Filip Pizlo', 'Antony L. Hosking', 'Tomas Kalibera', 'Jan Vitek'] scheduling hard real time garbage collection
# ['Jean Privat', 'Rachid Guerraoui', 'Filip Pizlo', 'Jan Vitek', 'Jesper Honig Spring'] reflexes abstractions for integrating highly responsive tasks into java applications
# ['Filip Pizlo', 'Jan Vitek'] memory management for real time java state of the art
# ['Ales Plsek', 'Jan Vitek', 'Daniel Tang'] memory safety for safety critical java
# ['Filip Pizlo', 'Anthony L. Hosking', 'Jan Vitek'] hierarchical real time garbage collection
# ['Jesper Honig Spring', 'Rachid Guerraoui', 'Jean Privat', 'Jan Vitek', 'Antonio Cunei'] high performance transactional event processing
# ['Tobias Wrigstad', 'Filip Pizlo', 'Jan Vitek', 'Fadi Meawad', 'Lei Zhao'] loci simple thread locality for java
# ['Filip Pizlo', 'Erez Petrank', 'Bjarne Steensgaard'] a study of concurrent real time garbage collectors
# ['Filip Pizlo', 'Bjarne Steensgaard', 'Daniel Frampton', 'Erez Petrank'] stopless a real time garbage collector for multiprocessors
#
# * 5/33 duplicated papers are removed.
# * 2 PIs, ['Jan Vitek', 'Antony L. Hosking']

# %%
plot_coauthor_net("0934218", title_printout=False)
# Out:
# * 9/139 duplicated papers are removed.
# * 4 PIs, ['Igal Szleifer', 'Fidel Santamaria', 'Dhiraj K. Sardar', 'Xomalin G. Peralta']
# Node 'Igal Szleifer' has no position.

# %%
plot_coauthor_net("0926127", title_printout=False)
# Out:
# * 1/59 duplicated papers are removed.
# * 5 PIs, ['Jason Cong', 'Jens Palsberg', 'Glenn Reinman', 'Vivek Sarkar', 'Alex A. T. Bui']

# %%
plot_coauthor_net("1027253", title_printout=False)
# Out:
# * 111/557 duplicated papers are removed.
# * 5 PIs, ['Douglas A. Landis', 'Katherine L. Gross', 'G. Philip Robertson', 'Thomas Schmidt', 'Stephen K. Hamilton']
# Node 'Thomas Schmidt' has no position.

# %%
plot_coauthor_net("0922742", title_printout=False)
# Out:
# * 6/57 duplicated papers are removed.
# * 5 PIs, ['Claude W. dePamphilis', 'Pamela S. Soltis', 'Jim Leebens-Mack', 'W. Brad Barbazuk', 'Victor A. Albert']
